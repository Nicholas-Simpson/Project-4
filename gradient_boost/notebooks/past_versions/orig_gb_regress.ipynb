# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# %%
# ID feature is already dropped from cleaning notebook
# Define the paths for all source files
cwd = os.getcwd()
orig_test_data_path = os.path.join(cwd,'wine_data','test.csv')
orig_train_data_path = os.path.join(cwd,'wine_data','train.csv')

# Open all source files as a pd dataframe
orig_test = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/test.csv')
orig_train = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/train.csv')
red_data = pd.read_csv('red_data_noID.csv')
white_data = pd.read_csv('white_data_noID.csv')
red_white_data = pd.read_csv('red_white_data_noID.csv')
trainable_data = pd.read_csv('trainable_data_noID.csv')

# Drop 'ID' columns
orig_test = orig_test.drop(columns='Id')
orig_train = orig_train.drop(columns='Id')

# %%
# Split the data into training and testing sets
X_train = orig_train.drop('quality', axis=1)
y_train = orig_train['quality'].copy()
X_test = orig_test.copy()
# y_test -= 3
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42) #because it is the answer :)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# Create a Gradient Boosting Regressor
model = GradientBoostingRegressor(random_state=42)

# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'subsample': [0.8, 1.0],
    'loss': ['ls', 'lad', 'huber']
}

# Perform grid search cross-validation
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=3)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.620 total time=   0.3s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.658 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.586 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.592 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.573 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.617 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.659 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.583 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.588 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.573 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.540 total time=   0.5s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.580 total time=   0.5s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.499 total time=   0.5s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.521 total time=   0.5s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.491 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.541 total time=   0.5s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.584 total time=   1.2s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.498 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.519 total time=   0.8s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.489 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.496 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.535 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.453 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.482 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.440 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.496 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.536 total time=   1.0s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.452 total time=   1.0s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.484 total time=   1.0s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.440 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.610 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.656 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.584 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.587 total time=   0.4s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.568 total time=   0.4s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.605 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.655 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.578 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.577 total time=   0.4s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.562 total time=   0.4s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.532 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.580 total time=   0.7s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.498 total time=   0.7s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.515 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.488 total time=   0.7s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.529 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.583 total time=   0.7s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.493 total time=   0.7s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.507 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.481 total time=   0.7s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.493 total time=   1.4s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.541 total time=   1.4s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.455 total time=   1.4s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.482 total time=   1.4s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.439 total time=   1.4s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.494 total time=   1.4s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.544 total time=   1.4s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.453 total time=   1.5s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.473 total time=   1.4s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.435 total time=   1.4s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.610 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.657 total time=   0.5s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.585 total time=   0.5s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.584 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.565 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.604 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.656 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.578 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.586 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.564 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.532 total time=   1.1s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.582 total time=   1.1s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.502 total time=   1.1s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.514 total time=   1.1s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.485 total time=   1.1s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.527 total time=   1.2s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.589 total time=   1.2s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.497 total time=   1.2s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.519 total time=   1.2s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.480 total time=   1.2s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.497 total time=   2.2s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.548 total time=   2.2s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.463 total time=   2.2s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.485 total time=   2.2s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.440 total time=   2.2s
# [CV 1/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.494 total time=   2.3s
# [CV 2/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.561 total time=   2.5s
# [CV 3/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.459 total time=   2.4s
# [CV 4/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.491 total time=   2.3s
# [CV 5/5] END learning_rate=0.01, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.437 total time=   2.3s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=ls, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=3, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=lad, max_depth=4, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# ...
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=4, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=50, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=100, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=0.8;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.2, loss=lad, max_depth=5, n_estimators=200, subsample=1.0;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.518 total time=   0.2s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.550 total time=   0.2s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.493 total time=   0.2s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.508 total time=   0.2s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=0.8;, score=-0.457 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.511 total time=   0.2s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.537 total time=   0.2s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.475 total time=   0.2s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.479 total time=   0.2s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=50, subsample=1.0;, score=-0.448 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.558 total time=   0.4s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.584 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.519 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.534 total time=   0.4s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=0.8;, score=-0.481 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.546 total time=   0.4s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.567 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.508 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.506 total time=   0.4s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=100, subsample=1.0;, score=-0.479 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.589 total time=   0.9s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.618 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.532 total time=   0.9s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.574 total time=   0.9s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=0.8;, score=-0.491 total time=   0.8s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.567 total time=   0.9s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.596 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.530 total time=   0.9s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.544 total time=   0.9s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=3, n_estimators=200, subsample=1.0;, score=-0.496 total time=   0.9s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.533 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.590 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.483 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.504 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=0.8;, score=-0.460 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.532 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.573 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.479 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.521 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=50, subsample=1.0;, score=-0.461 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.569 total time=   0.6s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.615 total time=   0.6s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.537 total time=   0.6s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.547 total time=   0.7s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=0.8;, score=-0.500 total time=   0.6s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.554 total time=   0.7s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.597 total time=   0.7s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.495 total time=   0.7s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.541 total time=   0.7s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=100, subsample=1.0;, score=-0.486 total time=   0.7s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.611 total time=   1.3s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.636 total time=   1.3s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.580 total time=   1.3s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.554 total time=   1.6s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=0.8;, score=-0.529 total time=   1.8s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.599 total time=   1.4s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.635 total time=   1.4s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.530 total time=   1.3s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.568 total time=   1.3s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=4, n_estimators=200, subsample=1.0;, score=-0.501 total time=   1.3s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.557 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.567 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.527 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.534 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=0.8;, score=-0.486 total time=   0.5s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.532 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.574 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.502 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.534 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=50, subsample=1.0;, score=-0.461 total time=   0.5s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.602 total time=   1.0s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.606 total time=   1.2s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.572 total time=   1.0s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.572 total time=   1.0s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=0.8;, score=-0.515 total time=   1.0s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.556 total time=   1.0s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.602 total time=   1.0s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.529 total time=   1.0s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.554 total time=   1.0s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=100, subsample=1.0;, score=-0.496 total time=   1.0s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.626 total time=   2.2s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.624 total time=   2.1s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.600 total time=   1.9s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.609 total time=   2.0s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=0.8;, score=-0.538 total time=   2.0s
# [CV 1/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.573 total time=   2.0s
# [CV 2/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.624 total time=   2.0s
# [CV 3/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.559 total time=   2.0s
# [CV 4/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.570 total time=   2.0s
# [CV 5/5] END learning_rate=0.2, loss=huber, max_depth=5, n_estimators=200, subsample=1.0;, score=-0.514 total time=   2.0s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'loss': ['ls', 'lad', 'huber'], 'max_depth': [3, 4, 5],
#                          'n_estimators': [50, 100, 200],
#                          'subsample': [0.8, 1.0]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
# Get the best parameters and the best model from the grid search 
best_params = grid_search.best_params_

# Train a model using the best parameters
best_model = GradientBoostingRegressor(random_state=42, **best_params)
best_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(loss='huber', n_estimators=50, random_state=42)

# %%
print(f"Best Parameters: {best_params}")

# Make predictions on the test set
y_pred = best_model.predict(X_val)

print(f"Training R-Squared: {best_model.score(X_train, y_train)}")
print(f"Testing R-Squared: {best_model.score(X_val, y_val)}")
print("Mean Squared Error:", mean_squared_error(y_val, y_val))
# Out:
# Best Parameters: {'learning_rate': 0.1, 'loss': 'huber', 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}
# Training R-Squared: 0.47472582044135037
# Testing R-Squared: 0.2998169938754842
# Mean Squared Error: 0.0
