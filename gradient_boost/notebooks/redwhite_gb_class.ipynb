# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, classification_report

# %%
# ID feature is already dropped from cleaning notebook
# Define the paths for all source files
cwd = os.getcwd()
orig_test_data_path = os.path.join(cwd,'wine_data','test.csv')
orig_train_data_path = os.path.join(cwd,'wine_data','train.csv')

# Open all source files as a pd dataframe
orig_test = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/test.csv')
orig_train = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/train.csv')
red_data = pd.read_csv('red_data_noID.csv')
white_data = pd.read_csv('white_data_noID.csv')
red_white_data = pd.read_csv('red_white_data_noID.csv')
trainable_data = pd.read_csv('trainable_data_noID.csv')

# Drop 'ID' columns
orig_test = orig_test.drop(columns='Id')
orig_train = orig_train.drop(columns='Id')

# %%
# Split the data into training and testing sets
X_train_redwhite = red_white_data.drop('quality', axis=1)
y_train_redwhite = red_white_data['quality'].copy()
X_test_redwhite = red_white_data.copy()
# y_test_redwhite -= 3
X_train_redwhite, X_val_redwhite, y_train_redwhite, y_val_redwhite = train_test_split(X_train_redwhite, 
                                                  y_train_redwhite, 
                                                  test_size = 0.2, 
                                                  random_state = 42) #because it is the answer :)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# Create a Gradient Boosting Regressor
redwhite_model = GradientBoostingClassifier()

# Define the hyperparameter grid to search
redwhite_param_grid = {
    'n_estimators': [50, 100, 200], # number of weak learning trees
    'learning_rate': [0.01, 0.1, 0.2], # control possibility of overfitting.
    # Strong interaction with n_estimators: smaller learning rates require more n_estimators
    'max_depth': [3, 5, 7] #  size of each tree
}

# Perform grid search with cross-validation
redwhite_grid_search = GridSearchCV(redwhite_model, redwhite_param_grid, cv=5, verbose=3)
redwhite_grid_search.fit(X_train_redwhite, y_train_redwhite)

# Get the best model from grid search
redwhite_best_gb = redwhite_grid_search.best_estimator_

# Make predictions on the test data using the best model
y_pred_redwhite = redwhite_best_gb.predict(X_val_redwhite)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.541 total time=   2.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.532 total time=   2.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.505 total time=   2.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.535 total time=   2.5s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.537 total time=   2.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.550 total time=   5.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.540 total time=   5.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.513 total time=   5.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.557 total time=   5.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.552 total time=   5.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.555 total time=  10.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.566 total time=  10.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.529 total time=  10.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.570 total time=  11.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.591 total time=  10.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.558 total time=   4.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.552 total time=   4.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.520 total time=   4.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.542 total time=   4.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.558 total time=   4.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.564 total time=   8.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.591 total time=   8.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.555 total time=   8.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.575 total time=   8.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.579 total time=   8.6s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.583 total time=  16.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.607 total time=  16.3s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.570 total time=  16.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.593 total time=  16.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.619 total time=  16.3s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.585 total time=   6.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.590 total time=   6.0s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.555 total time=   6.0s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.579 total time=   6.0s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.594 total time=   6.0s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.602 total time=  12.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.617 total time=  12.0s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.577 total time=  12.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.614 total time=  12.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.630 total time=  12.0s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.613 total time=  24.5s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.622 total time=  24.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.600 total time=  24.0s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.644 total time=  24.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.656 total time=  24.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.559 total time=   2.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.585 total time=   2.4s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.561 total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.577 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.605 total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.583 total time=   4.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.600 total time=   4.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.568 total time=   4.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.577 total time=   4.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.609 total time=   4.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.594 total time=   9.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.615 total time=   9.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.588 total time=  10.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.585 total time=   9.8s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.620 total time=   9.8s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.602 total time=   4.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.630 total time=   4.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.600 total time=   4.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.616 total time=   4.2s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.633 total time=   4.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.619 total time=   8.2s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.631 total time=   8.1s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.614 total time=   8.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.625 total time=   8.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.630 total time=   8.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.650 total time=  16.1s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.652 total time=  16.2s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.627 total time=  16.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.652 total time=  16.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.651 total time=  15.7s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.637 total time=   6.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.644 total time=   6.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.625 total time=   6.8s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.664 total time=   6.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.661 total time=   6.2s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.649 total time=  12.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.653 total time=  12.2s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.629 total time=  12.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.667 total time=  12.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.664 total time=  12.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.638 total time=  22.7s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.652 total time=  23.0s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.638 total time=  22.6s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.675 total time=  22.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.655 total time=  23.0s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.572 total time=   2.6s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.600 total time=   2.5s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.575 total time=   2.5s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.581 total time=   2.5s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.594 total time=   2.5s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.588 total time=   5.0s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.615 total time=   5.0s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.578 total time=   5.2s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.590 total time=   5.3s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.623 total time=   5.1s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.600 total time=   9.8s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.614 total time=   9.8s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.607 total time=   9.9s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.618 total time=   9.8s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.628 total time=   9.5s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.622 total time=   4.3s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.643 total time=   4.3s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.609 total time=   4.2s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.616 total time=   4.2s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.631 total time=   4.1s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.626 total time=   8.1s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.649 total time=   7.9s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.633 total time=   8.2s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.637 total time=   8.1s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.648 total time=   7.9s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.645 total time=  14.6s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.649 total time=  15.8s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.639 total time=  14.3s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.652 total time=  15.0s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.658 total time=  13.7s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.629 total time=   6.1s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.656 total time=   6.0s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.612 total time=   6.0s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.658 total time=   6.2s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.669 total time=   6.2s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.642 total time=  11.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.654 total time=  11.6s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.631 total time=  11.0s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.658 total time=  11.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.665 total time=  11.2s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.645 total time=  20.0s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.660 total time=  20.3s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.632 total time=  21.3s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.661 total time=  20.1s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.660 total time=  20.0s

# %%
# Calculate metrics
redwhite_accuracy = accuracy_score(y_val_redwhite, y_pred_redwhite)
# the following metrics need to include the average type since the validation is ordinal and not binary
redwhite_f1 = f1_score(y_val_redwhite, y_pred_redwhite, average= 'weighted')
redwhite_precision = precision_score(y_val_redwhite, y_pred_redwhite, average= 'weighted')
redwhite_recall = recall_score(y_val_redwhite, y_pred_redwhite, average= 'weighted')

print(f"Best Estimators: {redwhite_best_gb.n_estimators}")
print(f"Best Learning Rate: {redwhite_best_gb.learning_rate}")
print(f"Best Max Depth: {redwhite_best_gb.max_depth}")
print(f"Accuracy: {redwhite_accuracy:.2f}")
print(f"F1: {redwhite_f1:.2f}")
print(f"Precision: {redwhite_precision:.2f}")
print(f"Recall: {redwhite_recall:.2f}")
# Out:
# Best Estimators: 100
# Best Learning Rate: 0.1
# Best Max Depth: 7
# Accuracy: 0.67
# F1: 0.67
# Precision: 0.67
# Recall: 0.67

# %%
# Create a Gradient Boosting Regressor
redwhite_model_2 = GradientBoostingClassifier()

# Define the hyperparameter grid to search
redwhite_param_grid_2 = {
    'n_estimators': [50, 100, 200], # number of weak learning trees
    'learning_rate': [0.01, 0.1, 0.2], # control possibility of overfitting.
    # Strong interaction with n_estimators: smaller learning rates require more n_estimators
    'max_depth': [5, 7, 9] #  size of each tree
}

# Perform grid search with cross-validation
redwhite_grid_search_2 = GridSearchCV(redwhite_model_2, redwhite_param_grid_2, cv=5, verbose=3)
redwhite_grid_search_2.fit(X_train_redwhite, y_train_redwhite)

# Get the best model from grid search
redwhite_best_gb_2 = redwhite_grid_search_2.best_estimator_

# Make predictions on the test data using the best model
y_pred_redwhite_2 = redwhite_best_gb_2.predict(X_val_redwhite)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0

# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=200;, score=0.659 total time=  26.1s

# %%
# Calculate metrics
redwhite_accuracy_2 = accuracy_score(y_val_redwhite, y_pred_redwhite_2)
# the following metrics need to include the average type since the validation is ordinal and not binary
redwhite_f1_2 = f1_score(y_val_redwhite, y_pred_redwhite_2, average= 'weighted')
redwhite_precision_2 = precision_score(y_val_redwhite, y_pred_redwhite_2, average= 'weighted')
redwhite_recall_2 = recall_score(y_val_redwhite, y_pred_redwhite_2, average= 'weighted')

print(f"Best Estimators: {redwhite_best_gb_2.n_estimators}")
print(f"Best Learning Rate: {redwhite_best_gb_2.learning_rate}")
print(f"Best Max Depth: {redwhite_best_gb_2.max_depth}")
print(f"Accuracy: {redwhite_accuracy_2:.2f}")
print(f"F1: {redwhite_f1_2:.2f}")
print(f"Precision: {redwhite_precision_2:.2f}")
print(f"Recall: {redwhite_recall_2:.2f}")
# Out:
# Best Estimators: 200
# Best Learning Rate: 0.2
# Best Max Depth: 9
# Accuracy: 0.67
# F1: 0.67
# Precision: 0.68
# Recall: 0.67

# %%
redwhite_best_hp = redwhite_grid_search.best_params_
print(f"Best hp for 1st model: {redwhite_best_hp}")
print("---------------------------------")
print("Confusion Matrix:")
display(confusion_matrix(y_val_redwhite, y_pred_redwhite))
print("---------------------------------")
print(classification_report(y_val_redwhite,y_pred_redwhite))
# Out:
# Best hp for 1st model: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
# ---------------------------------
# Confusion Matrix:
# array([[  1,   0,   2,   2,   1,   0,   0],
#        [  1,   9,  24,   9,   0,   0,   0],
#        [  1,   4, 288, 103,   6,   0,   0],
#        [  2,   4, 109, 444,  35,   3,   0],
#        [  0,   0,   6,  85, 120,   3,   1],
#        [  0,   0,   0,  11,  12,  13,   0],
#        [  0,   0,   0,   1,   0,   0,   0]])
# ---------------------------------
#               precision    recall  f1-score   support
#
#            3       0.20      0.17      0.18         6
#            4       0.53      0.21      0.30        43
#            5       0.67      0.72      0.69       402
#            6       0.68      0.74      0.71       597
#            7       0.69      0.56      0.62       215
#            8       0.68      0.36      0.47        36
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.67      1300
#    macro avg       0.49      0.39      0.42      1300
# weighted avg       0.67      0.67      0.67      1300

# %%
redwhite_best_hp_2 = redwhite_grid_search_2.best_params_
print(f"Best hp for 2nd model: {redwhite_best_hp_2}")
print("---------------------------------")
print("Confusion Matrix:")
display(confusion_matrix(y_val_redwhite, y_pred_redwhite_2))
print("---------------------------------")
print(classification_report(y_val_redwhite,y_pred_redwhite_2))
# Out:
# Best hp for 2nd model: {'learning_rate': 0.2, 'max_depth': 9, 'n_estimators': 200}
# ---------------------------------
# Confusion Matrix:
# array([[  0,   0,   2,   2,   1,   0,   1],
#        [  1,   9,  24,   9,   0,   0,   0],
#        [  2,   2, 289, 103,   6,   0,   0],
#        [  3,   4, 106, 441,  41,   1,   1],
#        [  0,   0,   3,  86, 124,   1,   1],
#        [  0,   0,   0,  12,  11,  13,   0],
#        [  0,   0,   0,   1,   0,   0,   0]])
# ---------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.60      0.21      0.31        43
#            5       0.68      0.72      0.70       402
#            6       0.67      0.74      0.71       597
#            7       0.68      0.58      0.62       215
#            8       0.87      0.36      0.51        36
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.67      1300
#    macro avg       0.50      0.37      0.41      1300
# weighted avg       0.68      0.67      0.67      1300
