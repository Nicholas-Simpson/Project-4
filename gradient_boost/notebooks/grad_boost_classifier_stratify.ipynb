# %% [markdown]
# # Gradient Boosting Classifier Model with Stratify
# ---
# The following gadient boosted classifier parameter searches are a replicate of the base grad_boost_classifier notebook.
# * Each of the 4 searches have the same grid parameter search inputs
# * Within the train_test_split operation, a stratify term was added when splitting the training from the validation datasets. With the stratify parameter set to the distribution of quality scores within the original training dataset, the distribution of quality scores will be nearly the same bewteen the training and validation datasets.

# %%
import os
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay, cohen_kappa_score

import time

from warnings import filterwarnings
filterwarnings('ignore')

# %%
# The 'ID' feature is already dropped from cleaning notebook

# Open all source files as a pd dataframe
# This dataset will be used to train the gradient boosted model
orig_train = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/train.csv')

#This dataset will be used to evaluate again the Kaggle compitition entry submission
orig_test = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/test.csv')

# Addition datasets to explore the GradBoost model on actual wine data
red_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/gradient_boost/cleaned_data/red_white_data_noID.csv')
white_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/gradient_boost/cleaned_data/white_data_noID.csv')
red_white_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/gradient_boost/cleaned_data/red_white_data_noID.csv')
trainable_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/gradient_boost/cleaned_data/trainable_data_noID.csv')

# Drop 'ID' columns
orig_test = orig_test.drop(columns='Id')
orig_train = orig_train.drop(columns='Id')

# Create a place to save any generated files
gb_txt_output_path = os.path.join('../grad boost output','classification reports')
gb_png_output_path = os.path.join('../grad boost output','confusion plots')
os.makedirs(gb_txt_output_path, exist_ok = True)
os.makedirs( gb_png_output_path, exist_ok = True)

# %%
# Split the data into training and testing sets
X_train = orig_train.drop('quality', axis=1)
y_train = orig_train['quality'].copy()
X_test = orig_test.copy()
quality_rating = list(y_train)
X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                  y_train, 
                                                  stratify= quality_rating,
                                                  test_size = 0.2, 
                                                  random_state = 42) #because it is the answer :)

# %% [markdown]
# # Investigate Gradient Boosted Model Parameters

# %%
# Create a Gradient Boosting Regressor
model = GradientBoostingClassifier()

# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200], # number of weak learning trees
    'learning_rate': [0.01, 0.1, 0.2], # control possibility of overfitting.
    # Strong interaction with n_estimators: smaller learning rates require more n_estimators
    'max_depth': [3, 5, 7] #  size of each tree
}

# Perform grid search with cross-validation, mark timer start
start_time = time.time()
grid_search = GridSearchCV(model, param_grid, cv=5, verbose=3)
grid_search.fit(X_train, y_train)

# Get the best model from grid search
best_gb = grid_search.best_estimator_
grid_search_time = time.time()

# Make predictions on the test data using the best model
y_pred = best_gb.predict(X_val)

# Report how long it took to complete Grid search and prediction
end_time = time.time()
grid_time = grid_search_time - start_time
pred_time = end_time - grid_search_time
tot_time = end_time - start_time

print(f"Time to complete Grid Search: {grid_time:.6f} seconds")
print(f"Time to complete prediction: {pred_time:.6f} seconds")
print(f"Total time to complete Grid Search and prediction: {tot_time:.6f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.538 total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.578 total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.568 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.550 total time=   1.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.564 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.550 total time=   1.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.584 total time=   1.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.571 total time=   1.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.556 total time=   1.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.576 total time=   1.8s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.6s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.562 total time=   3.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.544 total time=   3.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.598 total time=   3.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.547 total time=   1.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.581 total time=   1.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.568 total time=   1.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.547 total time=   1.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.579 total time=   1.4s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.535 total time=   2.7s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.559 total time=   2.7s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.547 total time=   2.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.532 total time=   2.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.564 total time=   2.8s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.544 total time=   5.6s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.578 total time=   5.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.553 total time=   5.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.541 total time=   5.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.588 total time=   5.7s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.532 total time=   2.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.584 total time=   2.2s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.553 total time=   2.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.520 total time=   2.2s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.555 total time=   2.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.523 total time=   4.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.562 total time=   4.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.550 total time=   4.5s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.529 total time=   4.5s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.570 total time=   4.4s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.526 total time=   8.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.574 total time=   8.4s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.547 total time=   8.9s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.517 total time=   9.0s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.555 total time=   8.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.556 total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.553 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.538 total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.535 total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.595 total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.562 total time=   1.7s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.565 total time=   1.7s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.553 total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.535 total time=   1.7s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.573 total time=   1.8s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.508 total time=   3.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.568 total time=   3.6s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.529 total time=   3.4s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.526 total time=   3.6s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.555 total time=   3.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.514 total time=   1.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.559 total time=   1.4s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.550 total time=   1.4s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.535 total time=   1.4s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.573 total time=   1.4s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.505 total time=   2.8s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.562 total time=   2.7s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.538 total time=   2.7s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.495 total time=   2.8s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.561 total time=   2.7s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.508 total time=   5.4s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.571 total time=   5.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.547 total time=   5.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.520 total time=   5.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.546 total time=   5.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.517 total time=   2.3s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.562 total time=   2.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.568 total time=   2.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.517 total time=   2.2s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.582 total time=   2.2s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.495 total time=   4.6s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.571 total time=   4.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.556 total time=   4.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.523 total time=   4.5s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.588 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.492 total time=   8.6s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.578 total time=   8.2s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.532 total time=   8.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.535 total time=   8.4s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.585 total time=   9.0s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.541 total time=   0.8s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.581 total time=   0.8s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.559 total time=   0.8s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.529 total time=   0.8s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.576 total time=   0.8s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.489 total time=   1.6s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.602 total time=   1.7s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.532 total time=   1.8s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.529 total time=   1.8s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.561 total time=   1.7s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.489 total time=   3.3s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.565 total time=   3.3s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.538 total time=   3.3s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.523 total time=   3.3s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.530 total time=   3.4s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.520 total time=   1.5s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.553 total time=   1.4s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.517 total time=   1.4s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.508 total time=   1.4s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.527 total time=   1.5s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.492 total time=   2.9s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.559 total time=   2.7s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.495 total time=   2.8s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.511 total time=   2.8s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.552 total time=   3.0s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.498 total time=   5.2s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.568 total time=   5.0s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.498 total time=   5.0s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.517 total time=   5.1s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.552 total time=   5.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.505 total time=   2.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.559 total time=   2.3s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.520 total time=   2.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.517 total time=   2.2s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.573 total time=   2.2s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.495 total time=   4.1s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.571 total time=   4.2s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.538 total time=   4.3s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.511 total time=   4.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.576 total time=   4.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.520 total time=   6.8s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.599 total time=   6.6s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.517 total time=   6.8s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.532 total time=   6.8s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.582 total time=   6.7s
# Time to complete Grid Search: 458.299620 seconds
# Time to complete prediction: 0.008787 seconds
# Total time to complete Grid Search and prediction: 458.308407 seconds

# %%
# Create a Gradient Boosting Classifier with the best hyperparameters
best_params = {
    'n_estimators': best_gb.n_estimators,
    'learning_rate': best_gb.learning_rate,
    'max_depth': best_gb.max_depth
}
retrained_model = GradientBoostingClassifier(**best_params) # the ** tells python to unpack the dictionary

# Retrain the model on the entire training dataset
start_retrain = time.time()
retrained_model.fit(X_train, y_train)

# Make predictions on the validation set (or test set if needed) using the retrained model
y_pred_retrained = retrained_model.predict(X_val)
end_retrain = time.time()

# Calculate metrics
accuracy = accuracy_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred, average= 'weighted') # weighted average because the classification is not binary
precision = precision_score(y_val, y_pred, average= 'weighted')
recall = recall_score(y_val, y_pred, average= 'weighted')
kappa = cohen_kappa_score(y_val, y_pred, weights='quadratic')

# Determine how long it took to run model
retrain_time = end_retrain - start_retrain

print(f"Time to complete retrain model: {retrain_time:.4f}")
# Out:
# Time to complete retrain model: 3.8657

# %%
# Change the number of weak learner trees
# Create a Gradient Boosting Regressor
model_2 = GradientBoostingClassifier()

# Define the hyperparameter grid to search
param_grid_2 = {
    'n_estimators': [200, 400, 800],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [3, 5, 7]
}

# Perform grid search with cross-validation
start_time_2 = time.time()
grid_search_2 = GridSearchCV(model_2, param_grid_2, cv=5, verbose=3)
grid_search_2.fit(X_train, y_train)

# Get the best model from grid search
best_gb_2 = grid_search_2.best_estimator_
grid_search_time_2 = time.time()

# Make predictions on the test data using the best model
y_pred_2 = best_gb_2.predict(X_val)

# Report how long it took to complete Grid search and prediction
end_time_2 = time.time()
grid_time_2 = grid_search_time_2 - start_time_2
pred_time_2 = end_time_2 - grid_search_time_2
tot_time_2 = end_time_2 - start_time_2

print(f"Time to complete Grid Search: {grid_time_2:.6f} seconds")
print(f"Time to complete prediction: {pred_time_2:.6f} seconds")
print(f"Total time to complete Grid Search and prediction: {tot_time_2:.6f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.526 total time=   3.3s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.587 total time=   3.2s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.581 total time=   3.4s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.535 total time=   3.5s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.564 total time=   3.3s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.535 total time=   7.1s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.581 total time=   6.7s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.574 total time=   6.8s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.541 total time=   6.8s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.567 total time=   6.9s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.544 total time=  13.5s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.590 total time=  13.8s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.568 total time=  14.2s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.556 total time=  13.4s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.549 total time=  13.3s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.520 total time=   5.4s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.584 total time=   5.3s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.584 total time=   5.5s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.535 total time=   5.7s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.561 total time=   5.7s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.538 total time=  11.4s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.584 total time=  10.8s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.571 total time=  10.9s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.550 total time=  10.8s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.579 total time=  10.7s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.544 total time=  21.5s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.571 total time=  21.0s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.565 total time=  21.7s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.532 total time=  21.5s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.573 total time=  21.4s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.514 total time=   8.3s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.581 total time=   8.1s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.571 total time=   8.6s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.514 total time=   8.4s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.561 total time=   8.3s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.526 total time=  16.4s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.590 total time=  16.4s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.568 total time=  16.8s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.535 total time=  16.8s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.552 total time=  16.6s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.529 total time=  33.5s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.556 total time=  32.9s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.550 total time=  33.4s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.529 total time=  34.1s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.573 total time=  33.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.562 total time=   3.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.544 total time=   3.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.601 total time=   3.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.574 total time=   7.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.562 total time=   6.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.553 total time=   6.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.535 total time=   6.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.585 total time=   6.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.565 total time=  13.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.556 total time=  13.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.547 total time=  13.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.535 total time=  13.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.579 total time=  13.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.544 total time=   5.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.578 total time=   5.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.550 total time=   5.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.541 total time=   5.5s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.585 total time=   5.4s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.535 total time=  10.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.581 total time=  10.7s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.574 total time=  10.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.544 total time=  10.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.573 total time=  10.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.514 total time=  21.5s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.571 total time=  20.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.571 total time=  21.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.520 total time=  21.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.561 total time=  21.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.529 total time=   8.3s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.559 total time=   8.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.550 total time=   8.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.523 total time=   8.5s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.564 total time=   8.4s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.538 total time=  16.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.574 total time=  16.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.587 total time=  17.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.520 total time=  16.8s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.579 total time=  16.8s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.514 total time=  33.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.556 total time=  32.6s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.565 total time=  33.0s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.529 total time=  33.6s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.601 total time=  33.8s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.529 total time=   3.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.587 total time=   3.2s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.532 total time=   3.2s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.529 total time=   3.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.570 total time=   3.2s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.498 total time=   6.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.568 total time=   6.7s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.526 total time=   6.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.544 total time=   6.4s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.558 total time=   6.5s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.486 total time=  12.7s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.556 total time=  12.6s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.520 total time=  12.7s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.511 total time=  12.6s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.515 total time=  12.4s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.495 total time=   5.3s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.559 total time=   5.2s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.526 total time=   5.3s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.520 total time=   5.3s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.558 total time=   5.3s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.508 total time=   9.9s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.562 total time=  10.2s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.523 total time=   9.9s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.523 total time=   9.8s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.552 total time=   9.9s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.498 total time=  17.4s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.547 total time=  18.2s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.508 total time=  18.4s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.517 total time=  18.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.549 total time=  18.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.498 total time=   8.4s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.584 total time=   8.4s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.529 total time=   8.4s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.498 total time=   8.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.585 total time=   8.9s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.511 total time=  13.8s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.584 total time=  13.5s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.526 total time=  13.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.532 total time=  13.6s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.558 total time=  13.3s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.517 total time=  17.9s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.590 total time=  18.7s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.538 total time=  18.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.520 total time=  18.2s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.573 total time=  17.9s
# Time to complete Grid Search: 1675.998281 seconds
# Time to complete prediction: 0.009065 seconds
# Total time to complete Grid Search and prediction: 1676.007346 seconds

# %%
# Create a Gradient Boosting Classifier with the best hyperparameters to retrain the model to calculate computation timing
best_params_2 = {
    'n_estimators': best_gb_2.n_estimators,
    'learning_rate': best_gb_2.learning_rate,
    'max_depth': best_gb_2.max_depth
}
retrained_model_2 = GradientBoostingClassifier(**best_params_2) # the ** tells python to unpack the dictionary

# Retrain the model on the entire training dataset
start_retrain_2 = time.time()
retrained_model_2.fit(X_train, y_train)

# Make predictions on the validation set (or test set if needed) using the retrained model
y_pred_retrained_2 = retrained_model_2.predict(X_val)
end_retrain_2 = time.time()

# Calculate metrics
accuracy_2 = accuracy_score(y_val, y_pred_2)
# the following metrics need to include the average type since the validation is ordinal and not binary
f1_2 = f1_score(y_val, y_pred_2, average= 'weighted')
precision_2 = precision_score(y_val, y_pred_2, average= 'weighted')
recall_2 = recall_score(y_val, y_pred_2, average= 'weighted')
kappa_2 = cohen_kappa_score(y_val, y_pred_2, weights='quadratic')

# Determine how long it took to run model
retrain_time_2 = end_retrain_2 - start_retrain_2

print(f"Time to complete retrain model: {retrain_time_2:.4f}")
# Out:
# Time to complete retrain model: 3.7697

# %%
# Change the number of weak learner trees
# Create a Gradient Boosting Regressor
model_3 = GradientBoostingClassifier()

# Define the hyperparameter grid to search
param_grid_3 = {
    'n_estimators': [200, 400, 800],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [2, 3, 5]
}

# Perform grid search with cross-validation
start_time_3 = time.time()
grid_search_3 = GridSearchCV(model_3, param_grid_3, cv=5, verbose=3)
grid_search_3.fit(X_train, y_train)

# Get the best model from grid search
best_gb_3 = grid_search_3.best_estimator_
grid_search_time_3 = time.time()

# Make predictions on the test data using the best model
y_pred_3 = best_gb_3.predict(X_val)

# Report how long it took to complete Grid search and prediction
end_time_3 = time.time()
grid_time_3 = grid_search_time_3 - start_time_3
pred_time_3 = end_time_3 - grid_search_time_3
tot_time_3 = end_time_3 - start_time_3

print(f"Time to complete Grid Search: {grid_time_3:.6f} seconds")
print(f"Time to complete prediction: {pred_time_3:.6f} seconds")
print(f"Total time to complete Grid Search and prediction: {tot_time_3:.6f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=200;, score=0.532 total time=   2.5s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=200;, score=0.553 total time=   2.4s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=200;, score=0.571 total time=   2.4s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=200;, score=0.541 total time=   2.4s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=200;, score=0.561 total time=   2.4s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=400;, score=0.535 total time=   4.8s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=400;, score=0.590 total time=   4.9s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=400;, score=0.584 total time=   5.2s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=400;, score=0.538 total time=   4.8s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=400;, score=0.573 total time=   4.7s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=800;, score=0.544 total time=   9.5s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=800;, score=0.590 total time=   9.5s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=800;, score=0.614 total time=   9.5s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=800;, score=0.550 total time=   9.4s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=800;, score=0.573 total time=   9.5s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.526 total time=   3.2s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.587 total time=   3.3s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.581 total time=   3.3s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.535 total time=   3.2s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.564 total time=   3.2s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.535 total time=   6.4s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.581 total time=   6.4s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.574 total time=   6.4s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.541 total time=   6.6s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.567 total time=   6.6s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.544 total time=  13.2s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.590 total time=  13.1s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.568 total time=  13.0s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.556 total time=  13.4s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.549 total time=  13.1s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.523 total time=   5.8s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.581 total time=   5.8s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.584 total time=   5.6s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.535 total time=   5.5s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.561 total time=   5.4s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.538 total time=  10.8s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.584 total time=  10.6s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.571 total time=  10.7s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.550 total time=  10.8s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.579 total time=  11.1s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.544 total time=  21.7s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.571 total time=  21.3s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.565 total time=  21.4s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.532 total time=  21.6s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.573 total time=  22.2s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=200;, score=0.550 total time=   2.5s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=200;, score=0.593 total time=   2.5s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=200;, score=0.599 total time=   2.4s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=200;, score=0.550 total time=   2.4s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=200;, score=0.595 total time=   2.4s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=400;, score=0.584 total time=   4.8s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=400;, score=0.605 total time=   4.8s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=400;, score=0.574 total time=   4.8s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=400;, score=0.553 total time=   4.8s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=400;, score=0.591 total time=   4.8s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=800;, score=0.571 total time=   9.6s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=800;, score=0.602 total time=   9.5s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=800;, score=0.562 total time=   9.5s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=800;, score=0.553 total time=   9.8s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=800;, score=0.595 total time=   9.6s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.562 total time=   3.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.550 total time=   3.5s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.598 total time=   3.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.574 total time=   6.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.562 total time=   6.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.553 total time=   6.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.535 total time=   6.4s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.585 total time=   6.5s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.562 total time=  12.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.556 total time=  13.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.547 total time=  13.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.538 total time=  13.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.582 total time=  13.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.544 total time=   5.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.578 total time=   5.3s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.553 total time=   5.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.547 total time=   5.6s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.579 total time=   5.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.532 total time=  10.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.578 total time=  10.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.578 total time=  10.9s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.553 total time=  10.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.579 total time=  10.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.514 total time=  21.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.574 total time=  21.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.559 total time=  21.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.529 total time=  21.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.558 total time=  21.7s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=200;, score=0.526 total time=   2.4s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=200;, score=0.593 total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=200;, score=0.568 total time=   2.4s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=200;, score=0.556 total time=   2.5s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=200;, score=0.585 total time=   2.4s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=400;, score=0.502 total time=   4.8s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=400;, score=0.599 total time=   4.8s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=400;, score=0.535 total time=   4.8s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=400;, score=0.547 total time=   4.8s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=400;, score=0.579 total time=   4.8s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=800;, score=0.465 total time=   9.6s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=800;, score=0.584 total time=   9.7s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=800;, score=0.532 total time=   9.6s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=800;, score=0.541 total time=   9.6s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=800;, score=0.564 total time=   9.6s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.520 total time=   3.3s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.562 total time=   3.2s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.535 total time=   3.2s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.526 total time=   3.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.549 total time=   3.2s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.492 total time=   6.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.571 total time=   6.4s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.523 total time=   6.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.538 total time=   6.4s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.555 total time=   6.4s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.508 total time=  12.7s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.550 total time=  13.3s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.520 total time=  13.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.514 total time=  13.1s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.534 total time=  13.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.508 total time=   5.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.581 total time=   5.7s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.550 total time=   5.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.517 total time=   5.4s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.555 total time=   5.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.505 total time=  10.8s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.559 total time=  10.3s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.526 total time=  10.4s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.526 total time=  10.2s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.582 total time=  10.2s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.508 total time=  18.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.559 total time=  18.2s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.514 total time=  18.8s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.505 total time=  18.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.558 total time=  18.2s
# Time to complete Grid Search: 1150.656832 seconds
# Time to complete prediction: 0.011815 seconds
# Total time to complete Grid Search and prediction: 1150.668647 seconds

# %%
# Create a Gradient Boosting Classifier with the best hyperparameters to retrain the model to calculate computation timing
best_params_3 = {
    'n_estimators': best_gb_3.n_estimators,
    'learning_rate': best_gb_3.learning_rate,
    'max_depth': best_gb_3.max_depth
}
retrained_model_3 = GradientBoostingClassifier(**best_params_3) # the ** tells python to unpack the dictionary

# Retrain the model on the entire training dataset
start_retrain_3 = time.time()
retrained_model_3.fit(X_train, y_train)

# Make predictions on the validation set (or test set if needed) using the retrained model
y_pred_retrained_3 = retrained_model_3.predict(X_val)
end_retrain_3 = time.time()

# Calculate metrics
accuracy_3 = accuracy_score(y_val, y_pred_3)
# the following metrics need to include the average type since the validation is ordinal and not binary
f1_3 = f1_score(y_val, y_pred_3, average= 'weighted')
precision_3 = precision_score(y_val, y_pred_3, average= 'weighted')
recall_3 = recall_score(y_val, y_pred_3, average= 'weighted')
kappa_3 = cohen_kappa_score(y_val, y_pred_3, weights='quadratic')

# Determine how long it took to run model
retrain_time_3 = end_retrain_3 - start_retrain_3

print(f"Time to complete retrain model: {retrain_time_3:.4f}")
# Out:
# Time to complete retrain model: 5.6084

# %%
# Change the number of weak learner trees
# Create a Gradient Boosting Regressor
model_4 = GradientBoostingClassifier()

# Define the hyperparameter grid to search
param_grid_4 = {
    'n_estimators': [10, 20, 30, 40, 50, 75, 100, 150],
    'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.2],
    'max_depth': [2, 3, 5, 7, 9]
}

# Perform grid search with cross-validation
start_time_4 = time.time()
grid_search_4 = GridSearchCV(model_4, param_grid_4, cv=5, verbose=3)
grid_search_4.fit(X_train, y_train)

# Get the best model from grid search
best_gb_4 = grid_search_4.best_estimator_
grid_search_time_4 = time.time()

# Make predictions on the test data using the best model
y_pred_4 = best_gb_4.predict(X_val)

# Report how long it took to complete Grid search and prediction
end_time_4 = time.time()
grid_time_4 = grid_search_time_4 - start_time_4
pred_time_4 = end_time_4 - grid_search_time_4
tot_time_4 = end_time_4 - start_time_4

print(f"Time to complete Grid Search: {grid_time_4:.6f} seconds")
print(f"Time to complete prediction: {pred_time_4:.6f} seconds")
print(f"Total time to complete Grid Search and prediction: {tot_time_4:.6f} seconds")
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=10;, score=0.407 total time=   0.1s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=10;, score=0.407 total time=   0.1s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=10;, score=0.410 total time=   0.1s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=10;, score=0.407 total time=   0.1s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=10;, score=0.409 total time=   0.1s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=20;, score=0.407 total time=   0.3s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=20;, score=0.407 total time=   0.3s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=20;, score=0.410 total time=   0.3s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=20;, score=0.407 total time=   0.3s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=20;, score=0.409 total time=   0.3s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=30;, score=0.407 total time=   0.4s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=30;, score=0.407 total time=   0.4s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=30;, score=0.410 total time=   0.4s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=30;, score=0.407 total time=   0.4s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=30;, score=0.409 total time=   0.4s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=40;, score=0.407 total time=   0.5s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=40;, score=0.407 total time=   0.6s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=40;, score=0.410 total time=   0.5s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=40;, score=0.407 total time=   0.5s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=40;, score=0.409 total time=   0.5s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=50;, score=0.407 total time=   0.7s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=50;, score=0.407 total time=   0.6s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=50;, score=0.410 total time=   0.6s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=50;, score=0.407 total time=   0.6s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=50;, score=0.409 total time=   0.7s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=75;, score=0.511 total time=   0.9s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=75;, score=0.544 total time=   1.0s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=75;, score=0.541 total time=   0.9s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=75;, score=0.532 total time=   0.9s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=75;, score=0.543 total time=   1.0s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=100;, score=0.511 total time=   1.3s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=100;, score=0.544 total time=   1.2s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=100;, score=0.541 total time=   1.2s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=100;, score=0.532 total time=   1.3s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=100;, score=0.543 total time=   1.2s
# [CV 1/5] END learning_rate=0.001, max_depth=2, n_estimators=150;, score=0.511 total time=   1.8s
# [CV 2/5] END learning_rate=0.001, max_depth=2, n_estimators=150;, score=0.553 total time=   1.9s
# [CV 3/5] END learning_rate=0.001, max_depth=2, n_estimators=150;, score=0.562 total time=   1.9s
# [CV 4/5] END learning_rate=0.001, max_depth=2, n_estimators=150;, score=0.538 total time=   1.9s
# [CV 5/5] END learning_rate=0.001, max_depth=2, n_estimators=150;, score=0.555 total time=   1.9s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=10;, score=0.407 total time=   0.2s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=10;, score=0.407 total time=   0.2s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=10;, score=0.410 total time=   0.2s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=10;, score=0.407 total time=   0.2s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=10;, score=0.409 total time=   0.2s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=20;, score=0.407 total time=   0.3s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=20;, score=0.407 total time=   0.3s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=20;, score=0.410 total time=   0.3s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=20;, score=0.407 total time=   0.4s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=20;, score=0.409 total time=   0.3s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=30;, score=0.407 total time=   0.5s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=30;, score=0.407 total time=   0.5s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=30;, score=0.410 total time=   0.5s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=30;, score=0.407 total time=   0.5s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=30;, score=0.409 total time=   0.5s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=40;, score=0.407 total time=   0.7s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=40;, score=0.407 total time=   0.7s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=40;, score=0.410 total time=   1.0s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=40;, score=0.407 total time=   1.2s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=40;, score=0.409 total time=   1.3s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.453 total time=   1.0s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.444 total time=   0.9s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.435 total time=   0.9s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.447 total time=   0.8s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=50;, score=0.457 total time=   0.8s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=75;, score=0.508 total time=   1.3s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=75;, score=0.541 total time=   1.3s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=75;, score=0.532 total time=   1.3s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=75;, score=0.538 total time=   1.3s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=75;, score=0.537 total time=   1.3s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.526 total time=   1.8s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.556 total time=   1.6s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.565 total time=   1.7s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.541 total time=   1.7s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=100;, score=0.540 total time=   1.6s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=150;, score=0.529 total time=   2.6s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=150;, score=0.568 total time=   2.5s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=150;, score=0.568 total time=   2.4s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=150;, score=0.541 total time=   2.5s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=150;, score=0.549 total time=   2.5s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.407 total time=   0.3s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.407 total time=   0.3s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.410 total time=   0.3s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.407 total time=   0.3s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=10;, score=0.409 total time=   0.3s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=20;, score=0.407 total time=   0.5s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=20;, score=0.407 total time=   0.5s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=20;, score=0.410 total time=   0.5s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=20;, score=0.407 total time=   0.5s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=20;, score=0.409 total time=   0.6s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=30;, score=0.413 total time=   0.8s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=30;, score=0.407 total time=   0.8s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=30;, score=0.413 total time=   0.9s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=30;, score=0.404 total time=   0.8s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=30;, score=0.412 total time=   0.8s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=40;, score=0.444 total time=   1.1s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=40;, score=0.407 total time=   1.1s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=40;, score=0.480 total time=   1.1s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=40;, score=0.441 total time=   1.1s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=40;, score=0.457 total time=   1.1s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.459 total time=   1.4s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.480 total time=   1.4s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.511 total time=   1.4s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.505 total time=   1.4s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=50;, score=0.482 total time=   1.3s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=75;, score=0.520 total time=   2.1s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=75;, score=0.559 total time=   2.1s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=75;, score=0.559 total time=   2.3s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=75;, score=0.526 total time=   2.2s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=75;, score=0.515 total time=   2.2s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.529 total time=   2.8s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.581 total time=   2.8s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.565 total time=   2.8s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.529 total time=   2.8s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=100;, score=0.543 total time=   2.8s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=150;, score=0.520 total time=   4.1s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=150;, score=0.590 total time=   4.1s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=150;, score=0.581 total time=   4.5s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=150;, score=0.535 total time=   4.4s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=150;, score=0.546 total time=   4.1s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=10;, score=0.407 total time=   0.4s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=10;, score=0.407 total time=   0.5s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=10;, score=0.410 total time=   0.5s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=10;, score=0.407 total time=   0.4s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=10;, score=0.409 total time=   0.4s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=20;, score=0.407 total time=   0.8s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=20;, score=0.407 total time=   0.8s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=20;, score=0.410 total time=   0.8s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=20;, score=0.407 total time=   0.9s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=20;, score=0.409 total time=   0.8s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=30;, score=0.413 total time=   1.3s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=30;, score=0.429 total time=   1.3s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=30;, score=0.441 total time=   1.3s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=30;, score=0.426 total time=   1.4s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=30;, score=0.442 total time=   1.3s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=40;, score=0.444 total time=   1.7s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=40;, score=0.471 total time=   1.6s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=40;, score=0.474 total time=   1.8s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=40;, score=0.474 total time=   1.8s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=40;, score=0.482 total time=   1.7s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=50;, score=0.456 total time=   2.2s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=50;, score=0.495 total time=   2.1s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=50;, score=0.505 total time=   2.3s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=50;, score=0.502 total time=   2.2s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=50;, score=0.506 total time=   2.2s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=75;, score=0.495 total time=   3.1s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=75;, score=0.541 total time=   3.2s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=75;, score=0.532 total time=   3.3s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=75;, score=0.511 total time=   3.3s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=75;, score=0.527 total time=   3.2s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=100;, score=0.498 total time=   4.3s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=100;, score=0.568 total time=   4.3s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=100;, score=0.553 total time=   4.4s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=100;, score=0.511 total time=   4.4s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=100;, score=0.552 total time=   4.4s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=150;, score=0.514 total time=   6.2s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=150;, score=0.584 total time=   6.4s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=150;, score=0.559 total time=   6.8s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=150;, score=0.511 total time=   6.7s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=150;, score=0.546 total time=   6.5s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=10;, score=0.407 total time=   0.6s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=10;, score=0.407 total time=   0.6s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=10;, score=0.410 total time=   0.6s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=10;, score=0.407 total time=   0.6s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=10;, score=0.409 total time=   0.7s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=20;, score=0.407 total time=   1.2s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=20;, score=0.407 total time=   1.4s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=20;, score=0.410 total time=   1.3s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=20;, score=0.407 total time=   1.4s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=20;, score=0.409 total time=   1.3s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=30;, score=0.432 total time=   1.8s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=30;, score=0.468 total time=   1.9s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=30;, score=0.456 total time=   1.9s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=30;, score=0.447 total time=   1.9s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=30;, score=0.457 total time=   2.0s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=40;, score=0.453 total time=   2.6s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=40;, score=0.477 total time=   2.7s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=40;, score=0.474 total time=   2.6s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=40;, score=0.495 total time=   2.7s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=40;, score=0.485 total time=   2.7s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=50;, score=0.471 total time=   3.2s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=50;, score=0.498 total time=   3.4s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=50;, score=0.480 total time=   3.3s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=50;, score=0.498 total time=   3.3s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=50;, score=0.491 total time=   3.5s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=75;, score=0.486 total time=   4.9s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=75;, score=0.502 total time=   4.8s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=75;, score=0.505 total time=   4.9s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=75;, score=0.492 total time=   5.4s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=75;, score=0.524 total time=   5.2s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=100;, score=0.495 total time=   6.5s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=100;, score=0.514 total time=   6.7s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=100;, score=0.508 total time=   6.8s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=100;, score=0.502 total time=   6.8s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=100;, score=0.527 total time=   6.7s
# [CV 1/5] END learning_rate=0.001, max_depth=9, n_estimators=150;, score=0.502 total time=   9.5s
# [CV 2/5] END learning_rate=0.001, max_depth=9, n_estimators=150;, score=0.529 total time=   9.8s
# [CV 3/5] END learning_rate=0.001, max_depth=9, n_estimators=150;, score=0.514 total time=   9.7s
# [CV 4/5] END learning_rate=0.001, max_depth=9, n_estimators=150;, score=0.505 total time=  10.3s
# [CV 5/5] END learning_rate=0.001, max_depth=9, n_estimators=150;, score=0.521 total time=  10.0s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=10;, score=0.511 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=10;, score=0.544 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=10;, score=0.541 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=10;, score=0.532 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=10;, score=0.543 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=20;, score=0.532 total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=20;, score=0.556 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=20;, score=0.571 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=20;, score=0.541 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=20;, score=0.561 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=30;, score=0.535 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=30;, score=0.590 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=30;, score=0.574 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=30;, score=0.541 total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=30;, score=0.564 total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=40;, score=0.535 total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=40;, score=0.590 total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=40;, score=0.584 total time=   0.5s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=40;, score=0.544 total time=   0.5s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=40;, score=0.573 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.538 total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.590 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.587 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.538 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=50;, score=0.573 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=75;, score=0.544 total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=75;, score=0.584 total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=75;, score=0.608 total time=   1.0s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=75;, score=0.553 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=75;, score=0.582 total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.541 total time=   1.3s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.599 total time=   1.3s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.611 total time=   1.3s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.553 total time=   1.3s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=0.579 total time=   1.5s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=150;, score=0.541 total time=   1.9s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=150;, score=0.596 total time=   1.8s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=150;, score=0.599 total time=   1.9s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=150;, score=0.553 total time=   2.0s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=150;, score=0.598 total time=   1.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=10;, score=0.523 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=10;, score=0.556 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=10;, score=0.565 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=10;, score=0.541 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=10;, score=0.540 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=20;, score=0.526 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=20;, score=0.587 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=20;, score=0.581 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=20;, score=0.535 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=20;, score=0.564 total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=30;, score=0.532 total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=30;, score=0.581 total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=30;, score=0.590 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=30;, score=0.544 total time=   0.5s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=30;, score=0.567 total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=40;, score=0.538 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=40;, score=0.581 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=40;, score=0.574 total time=   0.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=40;, score=0.544 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=40;, score=0.567 total time=   0.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.538 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.578 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.568 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.550 total time=   0.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.564 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=75;, score=0.538 total time=   1.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=75;, score=0.587 total time=   1.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=75;, score=0.574 total time=   1.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=75;, score=0.556 total time=   1.4s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=75;, score=0.564 total time=   1.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.550 total time=   1.7s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.584 total time=   1.7s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.571 total time=   1.6s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.556 total time=   1.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.576 total time=   1.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=0.556 total time=   2.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=0.584 total time=   2.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=0.574 total time=   2.7s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=0.538 total time=   2.8s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=0.604 total time=   2.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.523 total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.581 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.565 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.532 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=10;, score=0.543 total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=20;, score=0.523 total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=20;, score=0.587 total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=20;, score=0.584 total time=   0.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=20;, score=0.535 total time=   0.5s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=20;, score=0.561 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=30;, score=0.535 total time=   0.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=30;, score=0.587 total time=   0.8s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=30;, score=0.578 total time=   0.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=30;, score=0.547 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=30;, score=0.573 total time=   0.8s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=40;, score=0.541 total time=   1.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=40;, score=0.587 total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=40;, score=0.568 total time=   1.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=40;, score=0.553 total time=   1.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=40;, score=0.579 total time=   1.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.544 total time=   1.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.581 total time=   1.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.562 total time=   1.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.547 total time=   2.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.576 total time=   1.8s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=75;, score=0.547 total time=   2.4s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=75;, score=0.574 total time=   2.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=75;, score=0.562 total time=   2.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=75;, score=0.532 total time=   2.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=75;, score=0.579 total time=   2.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.538 total time=   2.7s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.559 total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.553 total time=   2.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.532 total time=   2.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.564 total time=   2.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=0.547 total time=   4.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=0.578 total time=   4.0s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=0.547 total time=   4.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=0.547 total time=   4.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=0.579 total time=   4.0s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=10;, score=0.502 total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=10;, score=0.562 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=10;, score=0.553 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=10;, score=0.505 total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=10;, score=0.552 total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=20;, score=0.514 total time=   0.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=20;, score=0.574 total time=   0.8s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=20;, score=0.562 total time=   0.8s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=20;, score=0.514 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=20;, score=0.555 total time=   0.8s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=30;, score=0.526 total time=   1.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=30;, score=0.587 total time=   1.6s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=30;, score=0.562 total time=   1.7s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=30;, score=0.514 total time=   1.5s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=30;, score=0.564 total time=   1.5s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=40;, score=0.523 total time=   2.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=40;, score=0.587 total time=   1.9s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=40;, score=0.562 total time=   2.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=40;, score=0.526 total time=   2.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=40;, score=0.555 total time=   2.3s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.526 total time=   2.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.581 total time=   2.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.547 total time=   2.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.520 total time=   2.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.564 total time=   2.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=75;, score=0.526 total time=   3.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=75;, score=0.565 total time=   3.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=75;, score=0.550 total time=   3.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=75;, score=0.529 total time=   3.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=75;, score=0.561 total time=   3.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.529 total time=   4.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.541 total time=   4.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.559 total time=   4.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.529 total time=   4.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.567 total time=   4.3s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=0.535 total time=   6.6s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=0.568 total time=   6.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=0.547 total time=   6.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=0.523 total time=   6.4s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=0.549 total time=   6.4s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=10;, score=0.489 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=10;, score=0.511 total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=10;, score=0.495 total time=   0.7s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=10;, score=0.495 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=10;, score=0.524 total time=   0.7s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=20;, score=0.492 total time=   1.2s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=20;, score=0.532 total time=   1.3s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=20;, score=0.523 total time=   1.3s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=20;, score=0.529 total time=   1.3s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=20;, score=0.524 total time=   1.3s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=30;, score=0.511 total time=   1.9s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=30;, score=0.523 total time=   1.8s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=30;, score=0.532 total time=   1.9s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=30;, score=0.538 total time=   1.9s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=30;, score=0.555 total time=   2.1s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=40;, score=0.523 total time=   2.6s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=40;, score=0.535 total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=40;, score=0.547 total time=   2.8s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=40;, score=0.508 total time=   3.4s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=40;, score=0.564 total time=   2.9s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.520 total time=   3.6s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.529 total time=   3.4s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.547 total time=   3.3s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.538 total time=   3.4s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.561 total time=   3.4s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=75;, score=0.517 total time=   5.0s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=75;, score=0.526 total time=   4.9s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=75;, score=0.532 total time=   5.0s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=75;, score=0.523 total time=   5.0s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=75;, score=0.543 total time=   5.0s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.511 total time=   6.7s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.550 total time=   6.9s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.544 total time=   6.7s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.520 total time=   6.8s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.543 total time=   6.9s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=150;, score=0.520 total time=  10.2s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=150;, score=0.550 total time=   9.9s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=150;, score=0.553 total time=  10.2s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=150;, score=0.538 total time=   9.8s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=150;, score=0.546 total time=  10.0s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=10;, score=0.535 total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=10;, score=0.587 total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=10;, score=0.578 total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=10;, score=0.535 total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=10;, score=0.570 total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=20;, score=0.541 total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=20;, score=0.593 total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=20;, score=0.596 total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=20;, score=0.547 total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=20;, score=0.585 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=30;, score=0.544 total time=   0.4s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=30;, score=0.593 total time=   0.4s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=30;, score=0.599 total time=   0.4s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=30;, score=0.562 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=30;, score=0.598 total time=   0.5s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=40;, score=0.547 total time=   0.5s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=40;, score=0.596 total time=   0.5s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=40;, score=0.602 total time=   0.5s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=40;, score=0.559 total time=   0.5s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=40;, score=0.595 total time=   0.5s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.559 total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.599 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.587 total time=   0.7s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.562 total time=   0.7s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=50;, score=0.588 total time=   0.7s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=75;, score=0.584 total time=   0.9s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=75;, score=0.602 total time=   0.9s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=75;, score=0.571 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=75;, score=0.559 total time=   1.0s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=75;, score=0.588 total time=   1.1s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.581 total time=   1.3s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.599 total time=   1.2s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.571 total time=   1.3s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.550 total time=   1.3s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=0.598 total time=   1.3s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=150;, score=0.581 total time=   1.9s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=150;, score=0.602 total time=   1.9s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=150;, score=0.565 total time=   1.8s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=150;, score=0.547 total time=   2.1s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=150;, score=0.582 total time=   1.9s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=10;, score=0.541 total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=10;, score=0.587 total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=10;, score=0.571 total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=10;, score=0.550 total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=10;, score=0.564 total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=20;, score=0.541 total time=   0.4s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=20;, score=0.587 total time=   0.4s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=20;, score=0.568 total time=   0.4s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=20;, score=0.553 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=20;, score=0.570 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=30;, score=0.550 total time=   0.5s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=30;, score=0.578 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=30;, score=0.581 total time=   0.6s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=30;, score=0.538 total time=   0.5s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=30;, score=0.595 total time=   0.5s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=40;, score=0.559 total time=   0.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=40;, score=0.571 total time=   0.7s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=40;, score=0.568 total time=   0.7s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=40;, score=0.544 total time=   0.7s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=40;, score=0.604 total time=   0.7s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.571 total time=   0.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.568 total time=   0.9s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.571 total time=   0.9s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.547 total time=   0.9s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.595 total time=   0.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=75;, score=0.568 total time=   1.3s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=75;, score=0.562 total time=   1.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=75;, score=0.565 total time=   1.5s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=75;, score=0.532 total time=   1.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=75;, score=0.576 total time=   1.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.571 total time=   1.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.559 total time=   1.7s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.562 total time=   1.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.538 total time=   1.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.579 total time=   1.7s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=150;, score=0.556 total time=   2.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=150;, score=0.559 total time=   2.5s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=150;, score=0.556 total time=   2.5s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=150;, score=0.538 total time=   2.6s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=150;, score=0.576 total time=   2.8s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=10;, score=0.538 total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=10;, score=0.574 total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=10;, score=0.550 total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=10;, score=0.553 total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=10;, score=0.555 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=20;, score=0.544 total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=20;, score=0.565 total time=   0.5s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=20;, score=0.547 total time=   0.6s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=20;, score=0.541 total time=   0.6s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=20;, score=0.573 total time=   0.5s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=30;, score=0.550 total time=   0.9s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=30;, score=0.574 total time=   0.9s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=30;, score=0.556 total time=   0.8s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=30;, score=0.535 total time=   0.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=30;, score=0.570 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=40;, score=0.553 total time=   1.2s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=40;, score=0.571 total time=   1.2s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=40;, score=0.562 total time=   1.2s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=40;, score=0.547 total time=   1.3s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=40;, score=0.573 total time=   1.1s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.553 total time=   1.5s
# ...
# [CV 4/5] END learning_rate=0.2, max_depth=2, n_estimators=100;, score=0.550 total time=   1.2s
# [CV 5/5] END learning_rate=0.2, max_depth=2, n_estimators=100;, score=0.582 total time=   1.3s
# [CV 1/5] END learning_rate=0.2, max_depth=2, n_estimators=150;, score=0.514 total time=   1.8s
# [CV 2/5] END learning_rate=0.2, max_depth=2, n_estimators=150;, score=0.590 total time=   1.9s
# [CV 3/5] END learning_rate=0.2, max_depth=2, n_estimators=150;, score=0.532 total time=   1.8s
# [CV 4/5] END learning_rate=0.2, max_depth=2, n_estimators=150;, score=0.553 total time=   1.8s
# [CV 5/5] END learning_rate=0.2, max_depth=2, n_estimators=150;, score=0.591 total time=   1.8s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=10;, score=0.547 total time=   0.2s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=10;, score=0.556 total time=   0.2s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=10;, score=0.553 total time=   0.2s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=10;, score=0.550 total time=   0.2s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=10;, score=0.570 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=20;, score=0.556 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=20;, score=0.568 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=20;, score=0.553 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=20;, score=0.535 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=20;, score=0.570 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=30;, score=0.550 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=30;, score=0.553 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=30;, score=0.556 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=30;, score=0.538 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=30;, score=0.591 total time=   0.5s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=40;, score=0.541 total time=   0.6s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=40;, score=0.574 total time=   0.7s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=40;, score=0.562 total time=   0.7s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=40;, score=0.520 total time=   0.7s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=40;, score=0.582 total time=   0.7s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.532 total time=   0.8s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.556 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.556 total time=   0.8s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.529 total time=   0.9s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.585 total time=   0.9s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=75;, score=0.550 total time=   1.3s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=75;, score=0.584 total time=   1.2s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=75;, score=0.544 total time=   1.3s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=75;, score=0.535 total time=   1.2s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=75;, score=0.564 total time=   1.3s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.492 total time=   1.7s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.593 total time=   1.7s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.535 total time=   1.6s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.514 total time=   1.7s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.567 total time=   1.7s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=150;, score=0.529 total time=   2.4s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=150;, score=0.584 total time=   2.4s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=150;, score=0.544 total time=   2.6s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=150;, score=0.520 total time=   2.5s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=150;, score=0.524 total time=   2.5s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=10;, score=0.526 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=10;, score=0.547 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=10;, score=0.556 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=10;, score=0.517 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=10;, score=0.579 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=20;, score=0.529 total time=   0.6s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=20;, score=0.565 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=20;, score=0.541 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=20;, score=0.517 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=20;, score=0.555 total time=   0.6s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=30;, score=0.538 total time=   0.8s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=30;, score=0.550 total time=   0.8s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=30;, score=0.532 total time=   0.8s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=30;, score=0.517 total time=   0.8s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=30;, score=0.521 total time=   0.8s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=40;, score=0.514 total time=   1.1s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=40;, score=0.562 total time=   1.2s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=40;, score=0.523 total time=   1.1s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=40;, score=0.505 total time=   1.2s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=40;, score=0.573 total time=   1.1s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.517 total time=   1.4s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.571 total time=   1.5s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.523 total time=   1.5s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.526 total time=   1.4s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.552 total time=   1.4s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=75;, score=0.502 total time=   2.1s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=75;, score=0.565 total time=   2.1s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=75;, score=0.517 total time=   2.0s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=75;, score=0.502 total time=   2.0s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=75;, score=0.567 total time=   2.0s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.523 total time=   2.7s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.571 total time=   2.7s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.505 total time=   2.8s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.502 total time=   2.7s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.561 total time=   2.7s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=150;, score=0.505 total time=   3.9s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=150;, score=0.550 total time=   3.9s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=150;, score=0.505 total time=   3.9s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=150;, score=0.505 total time=   3.9s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=150;, score=0.564 total time=   4.0s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=10;, score=0.492 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=10;, score=0.565 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=10;, score=0.505 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=10;, score=0.465 total time=   0.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=10;, score=0.558 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=20;, score=0.505 total time=   0.9s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=20;, score=0.562 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=20;, score=0.517 total time=   0.9s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=20;, score=0.508 total time=   0.9s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=20;, score=0.543 total time=   1.0s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=30;, score=0.483 total time=   1.6s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=30;, score=0.581 total time=   1.6s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=30;, score=0.547 total time=   1.5s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=30;, score=0.498 total time=   1.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=30;, score=0.573 total time=   1.5s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=40;, score=0.492 total time=   1.9s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=40;, score=0.565 total time=   1.7s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=40;, score=0.541 total time=   1.9s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=40;, score=0.523 total time=   1.8s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=40;, score=0.570 total time=   1.8s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.486 total time=   2.3s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.532 total time=   2.2s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.547 total time=   2.2s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.511 total time=   2.1s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.564 total time=   2.4s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=75;, score=0.502 total time=   3.3s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=75;, score=0.565 total time=   3.2s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=75;, score=0.511 total time=   3.2s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=75;, score=0.511 total time=   3.3s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=75;, score=0.579 total time=   3.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.508 total time=   4.1s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.571 total time=   4.1s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.559 total time=   4.1s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.541 total time=   4.1s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.576 total time=   4.2s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=150;, score=0.489 total time=   5.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=150;, score=0.568 total time=   5.4s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=150;, score=0.544 total time=   5.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=150;, score=0.520 total time=   5.5s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=150;, score=0.579 total time=   5.6s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=10;, score=0.514 total time=   0.7s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=10;, score=0.538 total time=   0.7s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=10;, score=0.529 total time=   0.7s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=10;, score=0.523 total time=   0.7s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=10;, score=0.558 total time=   0.7s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=20;, score=0.492 total time=   1.5s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=20;, score=0.565 total time=   1.4s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=20;, score=0.553 total time=   1.4s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=20;, score=0.520 total time=   1.4s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=20;, score=0.534 total time=   1.4s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=30;, score=0.505 total time=   2.1s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=30;, score=0.562 total time=   2.1s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=30;, score=0.538 total time=   2.1s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=30;, score=0.529 total time=   2.0s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=30;, score=0.567 total time=   2.1s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=40;, score=0.526 total time=   2.8s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=40;, score=0.571 total time=   2.7s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=40;, score=0.553 total time=   2.7s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=40;, score=0.523 total time=   2.8s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=40;, score=0.549 total time=   2.8s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=50;, score=0.502 total time=   3.7s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=50;, score=0.578 total time=   3.7s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=50;, score=0.544 total time=   3.4s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=50;, score=0.529 total time=   3.4s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=50;, score=0.576 total time=   3.4s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=75;, score=0.495 total time=   4.7s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=75;, score=0.571 total time=   4.8s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=75;, score=0.535 total time=   4.8s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=75;, score=0.538 total time=   4.9s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=75;, score=0.558 total time=   5.0s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=100;, score=0.517 total time=   6.0s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=100;, score=0.562 total time=   5.8s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=100;, score=0.544 total time=   6.4s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=100;, score=0.535 total time=   6.1s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=100;, score=0.570 total time=   6.0s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=150;, score=0.529 total time=   7.2s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=150;, score=0.581 total time=   7.1s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=150;, score=0.547 total time=   7.3s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=150;, score=0.538 total time=   7.2s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=150;, score=0.588 total time=   7.4s
# Time to complete Grid Search: 1987.941537 seconds
# Time to complete prediction: 0.002819 seconds
# Total time to complete Grid Search and prediction: 1987.944356 seconds

# %%
# Create a Gradient Boosting Classifier with the best hyperparameters to retrain the model to calculate computation timing
best_params_4 = {
    'n_estimators': best_gb_4.n_estimators,
    'learning_rate': best_gb_4.learning_rate,
    'max_depth': best_gb_4.max_depth
}
retrained_model_4 = GradientBoostingClassifier(**best_params_4) # the ** tells python to unpack the dictionary

# Retrain the model on the entire training dataset
start_retrain_4 = time.time()
retrained_model_4.fit(X_train, y_train)

# Make predictions on the validation set (or test set if needed) using the retrained model
y_pred_retrained_4 = retrained_model_4.predict(X_val)
end_retrain_4 = time.time()

# Calculate metrics
accuracy_4 = accuracy_score(y_val, y_pred_4)
# the following metrics need to include the average type since the validation is ordinal and not binary
f1_4 = f1_score(y_val, y_pred_4, average= 'weighted')
precision_4 = precision_score(y_val, y_pred_4, average= 'weighted')
recall_4 = recall_score(y_val, y_pred_4, average= 'weighted')
kappa_4 = cohen_kappa_score(y_val, y_pred_4, weights='quadratic')

# Determine how long it took to run model
retrain_time_4 = end_retrain_4 - start_retrain_4

print(f"Time to complete retrain model: {retrain_time_4:.4f}")
# Out:
# Time to complete retrain model: 0.4982

# %% [markdown]
# # Classification Reports

# %%
CR_1 = classification_report(y_val,y_pred)

print("First Search Results:")
print("------------------------------------")
txt_file_name = f"{gb_txt_output_path}/gbc_st kappa: {kappa:.4f}   est: {best_gb.n_estimators}   LR: {best_gb.learning_rate}   depth: {best_gb.max_depth}  run_time: {retrain_time:.2f}.txt"
with open(txt_file_name, 'w') as txt_file:
    results=(
        f"Grid Search Parameters:\n"
        f"----------------------------------------------------------\n"
        f"Estimators used in grid search: {param_grid['n_estimators']}\n"
        f"Learning rates used in grid search: {param_grid['learning_rate']}\n"
        f"Tree node max depth in grid search: {param_grid['n_estimators']}\n"
        f"----------------------------------------------------------\n\n"
        
        f"Best Parameters Found:\n"
        f"----------------------------------------------------------\n"
        f"Best Estimators: {best_gb.n_estimators}\n"
        f"Best Learning Rate: {best_gb.learning_rate}\n"
        f"Best Max Depth: {best_gb.max_depth}\n"
        "----------------------------------------------------------\n\n"
        
        f"Classification Report\n"  
        f"-----------------------------------------------------------------------\n"
        f"{CR_1}\n"
        f"-----------------------------------------------------------------------\n\n"
        
        f"Model Performance:\n"
        f"----------------------------------------------------------\n"
        f"Accuracy: {accuracy:.2f}\n"
        f"F1: {f1:.2f}\n"
        f"Precision: {precision:.2f}\n"
        f"Recall: {recall:.2f}\n"
        f"Cohen Kappa Score, quadratic weighted: {kappa:.4f}\n"
        f"----------------------------------------------------------\n\n"

        f"Search and Training Duration\n"
        f"----------------------------------------------------------\n"
        f"Time to complete grid search: {grid_time:.6f} seconds\n"
        f"Time to run model with best params: {retrain_time:.6f} seconds\n"
        f"----------------------------------------------------------\n\n"
        f"***End Report***"
    )
    print(results)

    #save to txt file
    txt_file.write(results)
# Out:
# First Search Results:
# ------------------------------------
# Grid Search Parameters:
# ----------------------------------------------------------
# Estimators used in grid search: [50, 100, 200]
# Learning rates used in grid search: [0.01, 0.1, 0.2]
# Tree node max depth in grid search: [50, 100, 200]
# ----------------------------------------------------------
#
# Best Parameters Found:
# ----------------------------------------------------------
# Best Estimators: 200
# Best Learning Rate: 0.01
# Best Max Depth: 3
# ----------------------------------------------------------
#
# Classification Report
# -----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.72      0.72      0.72       168
#            6       0.52      0.64      0.57       156
#            7       0.49      0.36      0.41        67
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.59       412
#    macro avg       0.29      0.29      0.28       412
# weighted avg       0.57      0.59      0.58       412
#
# -----------------------------------------------------------------------
#
# Model Performance:
# ----------------------------------------------------------
# Accuracy: 0.59
# F1: 0.58
# Precision: 0.57
# Recall: 0.59
# Cohen Kappa Score, quadratic weighted: 0.5300
# ----------------------------------------------------------
#
# Search and Training Duration
# ----------------------------------------------------------
# Time to complete grid search: 458.299620 seconds
# Time to run model with best params: 3.865667 seconds
# ----------------------------------------------------------
#
# ***End Report***

# %%
CR_2 = classification_report(y_val,y_pred_2)

print("Second Search Resuults:")
print("------------------------------------")
txt_file_name = f"{gb_txt_output_path}/gbc_st kappa: {kappa_2:.4f}   est: {best_gb_2.n_estimators}   LR: {best_gb_2.learning_rate}   depth: {best_gb_2.max_depth}  run_time: {retrain_time_2:.2f}.txt"
with open(txt_file_name, 'w') as txt_file:
    results=(
        f"Grid Search Parameters:\n"
        f"----------------------------------------------------------\n"
        f"Estimators used in grid search: {param_grid_2['n_estimators']}\n"
        f"Learning rates used in grid search: {param_grid_2['learning_rate']}\n"
        f"Tree node max depth in grid search: {param_grid_2['n_estimators']}\n"
        f"----------------------------------------------------------\n\n"
        
        f"Best Parameters Found:\n"
        f"----------------------------------------------------------\n"
        f"Best Estimators: {best_gb_2.n_estimators}\n"
        f"Best Learning Rate: {best_gb_2.learning_rate}\n"
        f"Best Max Depth: {best_gb_2.max_depth}\n"
        "----------------------------------------------------------\n\n"

        f"Classification Report\n"  
        f"-----------------------------------------------------------------------\n"
        f"{CR_2}\n"
        f"-----------------------------------------------------------------------\n\n"
        
        f"Model Performance:\n"
        f"----------------------------------------------------------\n"
        f"Accuracy: {accuracy_2:.2f}\n"
        f"F1: {f1_2:.2f}\n"
        f"Precision: {precision_2:.2f}\n"
        f"Recall: {recall_2:.2f}\n"
        f"Cohen Kappa Score, quadratic weighted: {kappa_2:.4f}\n"
        f"----------------------------------------------------------\n\n"

        f"Search and Training Duration\n"
        f"----------------------------------------------------------\n"
        f"Time to complete grid search: {grid_time_2:.6f} seconds\n"
        f"Time to run model with best params: {retrain_time_2:.6f} seconds\n"
        f"----------------------------------------------------------\n\n"
        f"***End Report***"
    )
    print(results)

    #save to txt file
    txt_file.write(results)
# Out:
# Second Search Resuults:
# ------------------------------------
# Grid Search Parameters:
# ----------------------------------------------------------
# Estimators used in grid search: [200, 400, 800]
# Learning rates used in grid search: [0.001, 0.01, 0.1]
# Tree node max depth in grid search: [200, 400, 800]
# ----------------------------------------------------------
#
# Best Parameters Found:
# ----------------------------------------------------------
# Best Estimators: 200
# Best Learning Rate: 0.01
# Best Max Depth: 3
# ----------------------------------------------------------
#
# Classification Report
# -----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.72      0.72      0.72       168
#            6       0.52      0.64      0.57       156
#            7       0.49      0.36      0.41        67
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.59       412
#    macro avg       0.29      0.29      0.28       412
# weighted avg       0.57      0.59      0.58       412
#
# -----------------------------------------------------------------------
#
# Model Performance:
# ----------------------------------------------------------
# Accuracy: 0.59
# F1: 0.58
# Precision: 0.57
# Recall: 0.59
# Cohen Kappa Score, quadratic weighted: 0.5300
# ----------------------------------------------------------
#
# Search and Training Duration
# ----------------------------------------------------------
# Time to complete grid search: 1675.998281 seconds
# Time to run model with best params: 3.769736 seconds
# ----------------------------------------------------------
#
# ***End Report***

# %%
CR_3 = classification_report(y_val,y_pred_3)

print("Third Search Results:")
print("------------------------------------")
txt_file_name = f"{gb_txt_output_path}/gbc_st kappa: {kappa_3:.4f}   est: {best_gb_3.n_estimators}   LR: {best_gb_3.learning_rate}   depth: {best_gb_3.max_depth}  run_time: {retrain_time_3:.2f}.txt"
with open(txt_file_name, 'w') as txt_file:
    results=(
        f"Grid Search Parameters:\n"
        f"----------------------------------------------------------\n"
        f"Estimators used in grid search: {param_grid_3['n_estimators']}\n"
        f"Learning rates used in grid search: {param_grid_3['learning_rate']}\n"
        f"Tree node max depth in grid search: {param_grid_3['n_estimators']}\n"
        f"----------------------------------------------------------\n\n"
        
        f"Best Parameters Found:\n"
        f"----------------------------------------------------------\n"
        f"Best Estimators: {best_gb_3.n_estimators}\n"
        f"Best Learning Rate: {best_gb_3.learning_rate}\n"
        f"Best Max Depth: {best_gb_3.max_depth}\n"
        "----------------------------------------------------------\n\n"

        f"Classification Report\n"  
        f"-----------------------------------------------------------------------\n"
        f"{CR_3}\n"
        f"-----------------------------------------------------------------------\n\n"
        
        f"Model Performance:\n"
        f"----------------------------------------------------------\n"
        f"Accuracy: {accuracy_3:.2f}\n"
        f"F1: {f1_3:.2f}\n"
        f"Precision: {precision_3:.2f}\n"
        f"Recall: {recall_3:.2f}\n"
        f"Cohen Kappa Score, quadratic weighted: {kappa_3:.4f}\n"
        f"----------------------------------------------------------\n\n"

        f"Search and Training Duration\n"
        f"----------------------------------------------------------\n"
        f"Time to complete grid search: {grid_time_3:.6f} seconds\n"
        f"Time to run model with best params: {retrain_time_3:.6f} seconds\n"
        f"----------------------------------------------------------\n\n"
        f"***End Report***"
    )
    print(results)

    #save to txt file
    txt_file.write(results)
# Out:
# Third Search Results:
# ------------------------------------
# Grid Search Parameters:
# ----------------------------------------------------------
# Estimators used in grid search: [200, 400, 800]
# Learning rates used in grid search: [0.001, 0.01, 0.1]
# Tree node max depth in grid search: [200, 400, 800]
# ----------------------------------------------------------
#
# Best Parameters Found:
# ----------------------------------------------------------
# Best Estimators: 400
# Best Learning Rate: 0.01
# Best Max Depth: 2
# ----------------------------------------------------------
#
# Classification Report
# -----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.71      0.70      0.70       168
#            6       0.53      0.67      0.59       156
#            7       0.56      0.40      0.47        67
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.60       412
#    macro avg       0.30      0.30      0.29       412
# weighted avg       0.58      0.60      0.59       412
#
# -----------------------------------------------------------------------
#
# Model Performance:
# ----------------------------------------------------------
# Accuracy: 0.60
# F1: 0.59
# Precision: 0.58
# Recall: 0.60
# Cohen Kappa Score, quadratic weighted: 0.5239
# ----------------------------------------------------------
#
# Search and Training Duration
# ----------------------------------------------------------
# Time to complete grid search: 1150.656832 seconds
# Time to run model with best params: 5.608415 seconds
# ----------------------------------------------------------
#
# ***End Report***

# %%
CR_4 = classification_report(y_val,y_pred_4)

print("Fourth Search Results:")
print("------------------------------------")
txt_file_name = f"{gb_txt_output_path}/gbc_st kappa: {kappa_4:.4f}   est: {best_gb_4.n_estimators}   LR: {best_gb_4.learning_rate}   depth: {best_gb_4.max_depth}  run_time: {retrain_time_4:.2f}.txt"
with open(txt_file_name, 'w') as txt_file:
    results=(
        f"Grid Search Parameters:\n"
        f"----------------------------------------------------------\n"
        f"Estimators used in grid search: {param_grid_4['n_estimators']}\n"
        f"Learning rates used in grid search: {param_grid_4['learning_rate']}\n"
        f"Tree node max depth in grid search: {param_grid_4['n_estimators']}\n"
        f"----------------------------------------------------------\n\n"
        
        f"Best Parameters Found:\n"
        f"----------------------------------------------------------\n"
        f"Best Estimators: {best_gb_4.n_estimators}\n"
        f"Best Learning Rate: {best_gb_4.learning_rate}\n"
        f"Best Max Depth: {best_gb_4.max_depth}\n"
        "----------------------------------------------------------\n\n"

        f"Classification Report\n"  
        f"-----------------------------------------------------------------------\n"
        f"{CR_3}\n"
        f"-----------------------------------------------------------------------\n\n"
        
        
        f"Model Performance:\n"
        f"----------------------------------------------------------\n"
        f"Accuracy: {accuracy_4:.2f}\n"
        f"F1: {f1_4:.2f}\n"
        f"Precision: {precision_4:.2f}\n"
        f"Recall: {recall_4:.2f}\n"
        f"Cohen Kappa Score, quadratic weighted: {kappa_4:.4f}\n"
        f"----------------------------------------------------------\n\n"

        f"Search and Training Duration\n"
        f"----------------------------------------------------------\n"
        f"Time to complete grid search: {grid_time_4:.6f} seconds\n"
        f"Time to run model with best params: {retrain_time_4:.6f} seconds\n"
        f"----------------------------------------------------------\n\n"
        f"***End Report***"
    )
    print(results)

    #save to txt file
    txt_file.write(results)
# Out:
# Fourth Search Results:
# ------------------------------------
# Grid Search Parameters:
# ----------------------------------------------------------
# Estimators used in grid search: [10, 20, 30, 40, 50, 75, 100, 150]
# Learning rates used in grid search: [0.001, 0.01, 0.05, 0.1, 0.2]
# Tree node max depth in grid search: [10, 20, 30, 40, 50, 75, 100, 150]
# ----------------------------------------------------------
#
# Best Parameters Found:
# ----------------------------------------------------------
# Best Estimators: 30
# Best Learning Rate: 0.1
# Best Max Depth: 2
# ----------------------------------------------------------
#
# Classification Report
# -----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.71      0.70      0.70       168
#            6       0.53      0.67      0.59       156
#            7       0.56      0.40      0.47        67
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.60       412
#    macro avg       0.30      0.30      0.29       412
# weighted avg       0.58      0.60      0.59       412
#
# -----------------------------------------------------------------------
#
# Model Performance:
# ----------------------------------------------------------
# Accuracy: 0.61
# F1: 0.59
# Precision: 0.58
# Recall: 0.61
# Cohen Kappa Score, quadratic weighted: 0.5178
# ----------------------------------------------------------
#
# Search and Training Duration
# ----------------------------------------------------------
# Time to complete grid search: 1987.941537 seconds
# Time to run model with best params: 0.498160 seconds
# ----------------------------------------------------------
#
# ***End Report***

# %% [markdown]
# # Confusion Matrix

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (12,4.5))
grid_spec = GridSpec(3, 3, figure=fig, width_ratios = [1,1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs=  f"Learning Rate: {best_gb.learning_rate}, Tree Depth: {best_gb.max_depth}, Number of Trees: {best_gb.n_estimators}\n\nQuadratic Kappa Score: {kappa:.4f},  Model Compute Time: {retrain_time:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

# Confusion Matrix Subplot
conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred, ax=fig.add_subplot(grid_spec[2, 0]))
conf_matrix_display.ax_.set_title("Confusion Matrix")

# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
row_normalized_conf_matrix_display.ax_.set_title("Row Normalized Confusion Matrix")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 2]))
clm_normalized_conf_matrix_display.ax_.set_title("Column Normalized Confusion Matrix")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from First Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm kappa={kappa:.4f}  est: {best_gb.n_estimators}   LR: {best_gb.learning_rate}   depth: {best_gb.max_depth}  run_time: {retrain_time:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (8,4.5))
grid_spec = GridSpec(3, 2, figure=fig, width_ratios = [1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs=  f"Learning Rate: {best_gb.learning_rate}, Tree Depth: {best_gb.max_depth}, Number of Trees: {best_gb.n_estimators}\n\nQuadratic Kappa Score: {kappa:.4f},  Model Compute Time: {retrain_time:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

sample_weight = (y_pred != y_val)
# Row (True) Normalized Confusion Matrix Subplot
normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred,
                                                                         sample_weight = sample_weight,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 0]))
normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Row")

# Column (Predicted) Normalized Confusion Matrix Subplot
normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred,
                                                                         sample_weight = sample_weight,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Column")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from First Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm_err kappa={kappa:.4f}  est: {best_gb.n_estimators}   LR: {best_gb.learning_rate}   depth: {best_gb.max_depth}  run_time: {retrain_time:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (12,4.5))
grid_spec = GridSpec(3, 3, figure=fig, width_ratios = [1,1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs_2 =  f"Learning Rate: {best_gb_2.learning_rate}, Tree Depth: {best_gb_2.max_depth}, Number of Trees: {best_gb_2.n_estimators}\n\nQuadratic Kappa Score: {kappa_2:.4f},  Model Compute Time: {retrain_time_2:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs_2, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

# Confusion Matrix Subplot
conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2, ax=fig.add_subplot(grid_spec[2, 0]))
conf_matrix_display.ax_.set_title("Confusion Matrix")

# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
row_normalized_conf_matrix_display.ax_.set_title("Row Normalized Confusion Matrix")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 2]))
clm_normalized_conf_matrix_display.ax_.set_title("Column Normalized Confusion Matrix")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from Second Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm kappa={kappa_2:.4f}  est: {best_gb_2.n_estimators}   LR: {best_gb_2.learning_rate}   depth: {best_gb_2.max_depth}  run_time: {retrain_time_2:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (8,4.5))
grid_spec = GridSpec(3, 2, figure=fig, width_ratios = [1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs_2=  f"Learning Rate: {best_gb_2.learning_rate}, Tree Depth: {best_gb_2.max_depth}, Number of Trees: {best_gb_2.n_estimators}\n\nQuadratic Kappa Score: {kappa_2:.4f},  Model Compute Time: {retrain_time_2:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs_2, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

sample_weight = (y_pred_2 != y_val)
# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2,
                                                                         sample_weight = sample_weight,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 0]))
row_normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Row")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2,
                                                                         sample_weight = sample_weight,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
clm_normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Column")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from Second Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm_err kappa={kappa_2:.4f}  est: {best_gb_2.n_estimators}   LR: {best_gb_2.learning_rate}   depth: {best_gb_2.max_depth}  run_time: {retrain_time_2:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (12,4.5))
grid_spec = GridSpec(3, 3, figure=fig, width_ratios = [1,1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs_3 =  f"Learning Rate: {best_gb_3.learning_rate}, Tree Depth: {best_gb_3.max_depth}, Number of Trees: {best_gb_3.n_estimators}\n\nQuadratic Kappa Score: {kappa_3:.4f},  Model Compute Time: {retrain_time_3:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs_3, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

# Confusion Matrix Subplot
conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_3, ax=fig.add_subplot(grid_spec[2, 0]))
conf_matrix_display.ax_.set_title("Confusion Matrix")

# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_3,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
row_normalized_conf_matrix_display.ax_.set_title("Row Normalized Confusion Matrix")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_3,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 2]))
clm_normalized_conf_matrix_display.ax_.set_title("Column Normalized Confusion Matrix")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from Third Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm kappa={kappa_3:.4f}  est: {best_gb_3.n_estimators}   LR: {best_gb_3.learning_rate}   depth: {best_gb_3.max_depth}  run_time: {retrain_time_3:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (8,4.5))
grid_spec = GridSpec(3, 2, figure=fig, width_ratios = [1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs_3 =  f"Learning Rate: {best_gb_3.learning_rate}, Tree Depth: {best_gb_3.max_depth}, Number of Trees: {best_gb_3.n_estimators}\n\nQuadratic Kappa Score: {kappa_3:.4f},  Model Compute Time: {retrain_time_3:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs_3, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

sample_weight = (y_pred_3 != y_val)
# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_3,
                                                                         sample_weight = sample_weight,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 0]))
row_normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Row")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_3,
                                                                         sample_weight = sample_weight,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
clm_normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Column")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from Third Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm_err kappa={kappa_3:.4f}  est: {best_gb_3.n_estimators}   LR: {best_gb_3.learning_rate}   depth: {best_gb_3.max_depth}  run_time: {retrain_time_3:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (12,4.5))
grid_spec = GridSpec(3, 3, figure=fig, width_ratios = [1,1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs_4 =  f"Learning Rate: {best_gb_4.learning_rate}, Tree Depth: {best_gb_4.max_depth}, Number of Trees: {best_gb_4.n_estimators}\n\nQuadratic Kappa Score: {kappa_4:.4f},  Model Compute Time: {retrain_time_4:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs_4, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

# Confusion Matrix Subplot
conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_4, ax=fig.add_subplot(grid_spec[2, 0]))
conf_matrix_display.ax_.set_title("Confusion Matrix")

# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_4,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
row_normalized_conf_matrix_display.ax_.set_title("Row Normalized Confusion Matrix")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_4,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 2]))
clm_normalized_conf_matrix_display.ax_.set_title("Column Normalized Confusion Matrix")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from Fourth Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm kappa={kappa_4:.4f}  est: {best_gb_4.n_estimators}   LR: {best_gb_4.learning_rate}   depth: {best_gb_4.max_depth}  run_time: {retrain_time_4:.2f}.png"
plt.savefig(output_filename)
plt.show()

# %%
# Create the figure and gridspec
fig = plt.figure(figsize = (8,4.5))
grid_spec = GridSpec(3, 2, figure=fig, width_ratios = [1,1], height_ratios=[1,2,10])

# Model specs subplot
model_specs_4 =  f"Learning Rate: {best_gb_4.learning_rate}, Tree Depth: {best_gb_4.max_depth}, Number of Trees: {best_gb_4.n_estimators}\n\nQuadratic Kappa Score: {kappa_4:.4f},  Model Compute Time: {retrain_time_4:.2f} sec"   
center_ax = fig.add_subplot(grid_spec[1, :])

# plt.center_ax_adjust(hspace = 0.5)
center_text = center_ax.text(0.5, 0.55, model_specs_4, ha='center', fontsize=12,
                           bbox=dict(facecolor='lightgray', alpha=0.5, boxstyle='round,pad=0.5'))
center_ax.axis('off')

sample_weight = (y_pred_4 != y_val)
# Row (True) Normalized Confusion Matrix Subplot
row_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_4,
                                                                         sample_weight = sample_weight,
                                                                         normalize='true',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 0]))
row_normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Row")

# Column (Predicted) Normalized Confusion Matrix Subplot
clm_normalized_conf_matrix_display = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_4,
                                                                         sample_weight = sample_weight,
                                                                         normalize='pred',
                                                                         values_format='.0%',
                                                                         ax=fig.add_subplot(grid_spec[2, 1]))
clm_normalized_conf_matrix_display.ax_.set_title("Errors Normalized by Column")

# Adjust Layout
plt.tight_layout()
fig.suptitle("Confusion Matrix from Fourth Gradient Boosted Search", fontsize=20)

# Save and show the figure
output_filename = f"{gb_png_output_path}/gb_st_cm_err kappa={kappa_4:.4f}  est: {best_gb_4.n_estimators}   LR: {best_gb_4.learning_rate}   depth: {best_gb_4.max_depth}  run_time: {retrain_time_4:.2f}.png"
plt.savefig(output_filename)
plt.show()
