# %%
# Dependencies and Setup
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import the OpenWeatherMap API key
from api_keys import weather_api_key, visualcrossing_key

# %%
# Set the API base URL
url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/dayton%2520oregon/2023-07-01/2023-08-19?elements=datetime%2CdatetimeEpoch%2Ctemp%2Ctempmax%2Ctempmin%2Cprecip%2Cwindspeed%2Cwindgust%2Cfeelslike%2Cfeelslikemax%2Cfeelslikemin%2Cpressure%2Cstations%2Cdegreedays%2Caccdegreedays&include=fcst%2Cobs%2Chistfcst%2Cstats%2Chours&key={visualcrossing_key}&options=preview&contentType=json"

dayton = requests.get(url)

# %%
dayton_df = pd.DataFrame(dayton)
print(dayton_df[0])
# Out:
# 0    b'You have exceeded the maximum number of dail...
# 1                                           b'esults.'
# Name: 0, dtype: object

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | constantia
# Processing Record 4 of Set 1 | renfrew
# Processing Record 5 of Set 1 | kuraymah
# Processing Record 6 of Set 1 | sonsorol village
# City not found. Skipping...
# Processing Record 7 of Set 1 | wang sai phun
# Processing Record 8 of Set 1 | horta
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | livingston
# Processing Record 12 of Set 1 | puerto natales
# Processing Record 13 of Set 1 | alice springs
# Processing Record 14 of Set 1 | san rafael
# Processing Record 15 of Set 1 | college station
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | alice town
# Processing Record 18 of Set 1 | springs
# Processing Record 19 of Set 1 | papatowai
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | kachug
# Processing Record 22 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 23 of Set 1 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 24 of Set 1 | qaqortoq
# Processing Record 25 of Set 1 | olonkinbyen
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | santa marta de tormes
# Processing Record 29 of Set 1 | bria
# Processing Record 30 of Set 1 | san luis
# Processing Record 31 of Set 1 | remire-montjoly
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | port alberni
# Processing Record 34 of Set 1 | igra
# Processing Record 35 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | sydney
# Processing Record 38 of Set 1 | edinburgh of the seven seas
# Processing Record 39 of Set 1 | seven pagodas
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | puerto baquerizo moreno
# Processing Record 42 of Set 1 | margaret river
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | salekhard
# Processing Record 45 of Set 1 | chumphon
# Processing Record 46 of Set 1 | ushtobe
# Processing Record 47 of Set 1 | kristiansund
# Processing Record 48 of Set 1 | nguekhokh
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 0 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 1 of Set 2 | okhotsk
# Processing Record 2 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 3 of Set 2 | mopti
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | freetown
# Processing Record 6 of Set 2 | whitehorse
# Processing Record 7 of Set 2 | nemuro
# Processing Record 8 of Set 2 | verkhnevilyuysk
# Processing Record 9 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 2 | aoulef
# Processing Record 11 of Set 2 | cooma
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | dar naim
# City not found. Skipping...
# Processing Record 14 of Set 2 | fisterra
# Processing Record 15 of Set 2 | kourou
# Processing Record 16 of Set 2 | bilibino
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | zaysan
# Processing Record 19 of Set 2 | st. john's
# Processing Record 20 of Set 2 | farafangana
# Processing Record 21 of Set 2 | kingston
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | angaur state
# Processing Record 24 of Set 2 | nabire
# Processing Record 25 of Set 2 | lerwick
# Processing Record 26 of Set 2 | kampene
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | camaiore
# Processing Record 30 of Set 2 | nar'yan-mar
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | mbanza-ngungu
# Processing Record 33 of Set 2 | barreiras
# Processing Record 34 of Set 2 | bangassou
# Processing Record 35 of Set 2 | kolonia
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | ceeldheer
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | pisco
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | namibe
# Processing Record 44 of Set 2 | kundiawa
# Processing Record 45 of Set 2 | daru
# Processing Record 46 of Set 2 | chui
# Processing Record 47 of Set 2 | bugiri
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | jalai nur
# Processing Record 0 of Set 3 | arafat
# Processing Record 1 of Set 3 | izluchinsk
# Processing Record 2 of Set 3 | bougouni
# Processing Record 3 of Set 3 | motygino
# Processing Record 4 of Set 3 | opuwo
# Processing Record 5 of Set 3 | isafjordur
# Processing Record 6 of Set 3 | atafu village
# Processing Record 7 of Set 3 | sirte
# Processing Record 8 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 3 | susuman
# Processing Record 10 of Set 3 | porkhov
# Processing Record 11 of Set 3 | vorgashor
# Processing Record 12 of Set 3 | tura
# Processing Record 13 of Set 3 | taroa
# Processing Record 14 of Set 3 | kiunga
# Processing Record 15 of Set 3 | kupang
# Processing Record 16 of Set 3 | valparaiso
# Processing Record 17 of Set 3 | bushland beach
# City not found. Skipping...
# Processing Record 18 of Set 3 | san pedro pochutla
# Processing Record 19 of Set 3 | aykhal
# Processing Record 20 of Set 3 | kapshagay
# Processing Record 21 of Set 3 | sylvan lake
# Processing Record 22 of Set 3 | mormugao
# Processing Record 23 of Set 3 | stanley
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | mokwa
# Processing Record 26 of Set 3 | west island
# Processing Record 27 of Set 3 | demre
# Processing Record 28 of Set 3 | iskateley
# Processing Record 29 of Set 3 | udachny
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | hobyo
# Processing Record 32 of Set 3 | kudahuvadhoo
# Processing Record 33 of Set 3 | brezina
# Processing Record 34 of Set 3 | west bay
# Processing Record 35 of Set 3 | ciudad lazaro cardenas
# Processing Record 36 of Set 3 | wailua homesteads
# Processing Record 37 of Set 3 | cadillac
# Processing Record 38 of Set 3 | la ronge
# Processing Record 39 of Set 3 | carutapera
# Processing Record 40 of Set 3 | susanville
# Processing Record 41 of Set 3 | sol'-iletsk
# Processing Record 42 of Set 3 | vegreville
# Processing Record 43 of Set 3 | verkhotur'ye
# Processing Record 44 of Set 3 | lethem
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | happy valley-goose bay
# Processing Record 47 of Set 3 | chillan
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | saldanha
# Processing Record 0 of Set 4 | olhao
# Processing Record 1 of Set 4 | invercargill
# Processing Record 2 of Set 4 | san antonio de pale
# Processing Record 3 of Set 4 | dakhla
# Processing Record 4 of Set 4 | chizhou
# Processing Record 5 of Set 4 | guerrero negro
# Processing Record 6 of Set 4 | utrik
# Processing Record 7 of Set 4 | zira
# Processing Record 8 of Set 4 | siwa oasis
# Processing Record 9 of Set 4 | fort mcmurray
# Processing Record 10 of Set 4 | nouadhibou
# Processing Record 11 of Set 4 | nagqu
# Processing Record 12 of Set 4 | waingapu
# Processing Record 13 of Set 4 | talara
# Processing Record 14 of Set 4 | blackmans bay
# Processing Record 15 of Set 4 | severo-yeniseyskiy
# Processing Record 16 of Set 4 | tsiombe
# Processing Record 17 of Set 4 | popondetta
# Processing Record 18 of Set 4 | conception bay south
# Processing Record 19 of Set 4 | santa vitoria
# Processing Record 20 of Set 4 | inarajan village
# Processing Record 21 of Set 4 | queenstown
# Processing Record 22 of Set 4 | piacabucu
# Processing Record 23 of Set 4 | selfoss
# Processing Record 24 of Set 4 | kem'
# Processing Record 25 of Set 4 | aleg
# Processing Record 26 of Set 4 | hadibu
# Processing Record 27 of Set 4 | priob'ye
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | hadim
# Processing Record 30 of Set 4 | cruzeiro do sul
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | kenai
# Processing Record 33 of Set 4 | bagaha
# Processing Record 34 of Set 4 | recani
# Processing Record 35 of Set 4 | port mathurin
# Processing Record 36 of Set 4 | tingi
# Processing Record 37 of Set 4 | baruun-urt
# Processing Record 38 of Set 4 | lichinga
# Processing Record 39 of Set 4 | lihue
# Processing Record 40 of Set 4 | usogorsk
# Processing Record 41 of Set 4 | puerto aysen
# Processing Record 42 of Set 4 | xilin hot
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | penjamo
# Processing Record 45 of Set 4 | ushuaia
# Processing Record 46 of Set 4 | cherpulassery
# Processing Record 47 of Set 4 | tarawa
# Processing Record 48 of Set 4 | manuguru
# Processing Record 49 of Set 4 | marquette
# Processing Record 0 of Set 5 | alto barinas
# Processing Record 1 of Set 5 | egilsstadir
# Processing Record 2 of Set 5 | ceres
# Processing Record 3 of Set 5 | santa ana
# Processing Record 4 of Set 5 | westport
# Processing Record 5 of Set 5 | bamboo flat
# Processing Record 6 of Set 5 | nelson bay
# Processing Record 7 of Set 5 | vilyuchinsk
# Processing Record 8 of Set 5 | ostroda
# Processing Record 9 of Set 5 | new kingman-butler
# Processing Record 10 of Set 5 | vila velha
# Processing Record 11 of Set 5 | sukumo
# Processing Record 12 of Set 5 | saipan
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | macaubas
# Processing Record 15 of Set 5 | amursk
# Processing Record 16 of Set 5 | mufulira
# Processing Record 17 of Set 5 | xinpu
# Processing Record 18 of Set 5 | the bottom
# Processing Record 19 of Set 5 | sarupathar
# Processing Record 20 of Set 5 | mastic beach
# Processing Record 21 of Set 5 | chonchi
# Processing Record 22 of Set 5 | bubaque
# Processing Record 23 of Set 5 | vorkuta
# Processing Record 24 of Set 5 | flin flon
# Processing Record 25 of Set 5 | hawaiian paradise park
# Processing Record 26 of Set 5 | san luis de la loma
# Processing Record 27 of Set 5 | zhezqazghan
# Processing Record 28 of Set 5 | bredasdorp
# Processing Record 29 of Set 5 | almhult
# City not found. Skipping...
# Processing Record 30 of Set 5 | ksar el kebir
# Processing Record 31 of Set 5 | nyrob
# Processing Record 32 of Set 5 | shumikha
# Processing Record 33 of Set 5 | ayaguz
# City not found. Skipping...
# Processing Record 34 of Set 5 | copiapo
# Processing Record 35 of Set 5 | thunder bay
# Processing Record 36 of Set 5 | san julian
# Processing Record 37 of Set 5 | plastun
# Processing Record 38 of Set 5 | agva
# City not found. Skipping...
# Processing Record 39 of Set 5 | khandyga
# Processing Record 40 of Set 5 | filipstad
# Processing Record 41 of Set 5 | ancud
# Processing Record 42 of Set 5 | martapura
# Processing Record 43 of Set 5 | birjand
# Processing Record 44 of Set 5 | folkston
# Processing Record 45 of Set 5 | kolonia town
# Processing Record 46 of Set 5 | kamina
# Processing Record 47 of Set 5 | bakshwaho
# Processing Record 48 of Set 5 | ust-tsilma
# Processing Record 49 of Set 5 | kavieng
# Processing Record 0 of Set 6 | villa gesell
# Processing Record 1 of Set 6 | kodiak
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | gamay
# Processing Record 4 of Set 6 | pervomaysk
# Processing Record 5 of Set 6 | sandnessjoen
# Processing Record 6 of Set 6 | castillos
# Processing Record 7 of Set 6 | mili
# Processing Record 8 of Set 6 | antsohihy
# Processing Record 9 of Set 6 | la reforma
# Processing Record 10 of Set 6 | abraham's bay
# City not found. Skipping...
# Processing Record 11 of Set 6 | haiku-pauwela
# Processing Record 12 of Set 6 | ardakan
# Processing Record 13 of Set 6 | ladismith
# City not found. Skipping...
# Processing Record 14 of Set 6 | son ferrer
# City not found. Skipping...
# Processing Record 15 of Set 6 | polyarnyy
# Processing Record 16 of Set 6 | badger
# Processing Record 17 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 6 | fortuna
# Processing Record 19 of Set 6 | san pedro
# Processing Record 20 of Set 6 | al lagowa
# Processing Record 21 of Set 6 | port augusta
# Processing Record 22 of Set 6 | malango
# Processing Record 23 of Set 6 | yung shue wan
# Processing Record 24 of Set 6 | arraial do cabo
# Processing Record 25 of Set 6 | kununurra
# Processing Record 26 of Set 6 | broome
# Processing Record 27 of Set 6 | afaahiti
# Processing Record 28 of Set 6 | juan griego
# Processing Record 29 of Set 6 | porto novo
# Processing Record 30 of Set 6 | altay
# Processing Record 31 of Set 6 | keflavik
# Processing Record 32 of Set 6 | adh dhibiyah
# City not found. Skipping...
# Processing Record 33 of Set 6 | tolanaro
# Processing Record 34 of Set 6 | ust-nera
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | tabuk
# Processing Record 37 of Set 6 | ciudad general teran
# Processing Record 38 of Set 6 | mount pearl
# Processing Record 39 of Set 6 | yatou
# Processing Record 40 of Set 6 | roja
# Processing Record 41 of Set 6 | tobelo
# Processing Record 42 of Set 6 | berezovyy
# Processing Record 43 of Set 6 | mariental
# Processing Record 44 of Set 6 | kidal
# Processing Record 45 of Set 6 | escanaba
# Processing Record 46 of Set 6 | al kharijah
# Processing Record 47 of Set 6 | turkmenbasy
# Processing Record 48 of Set 6 | matias barbosa
# Processing Record 49 of Set 6 | itoman
# Processing Record 0 of Set 7 | auki
# Processing Record 1 of Set 7 | xai-xai
# Processing Record 2 of Set 7 | minggang
# Processing Record 3 of Set 7 | tofol
# Processing Record 4 of Set 7 | hammerfest
# Processing Record 5 of Set 7 | ar rutbah
# Processing Record 6 of Set 7 | klyuchi
# Processing Record 7 of Set 7 | kismayo
# Processing Record 8 of Set 7 | xiaoweizhai
# Processing Record 9 of Set 7 | uturoa
# Processing Record 10 of Set 7 | ardabil
# Processing Record 11 of Set 7 | murun-kuren
# Processing Record 12 of Set 7 | portstewart
# Processing Record 13 of Set 7 | kabompo
# Processing Record 14 of Set 7 | darnah
# Processing Record 15 of Set 7 | zouerate
# Processing Record 16 of Set 7 | akureyri
# Processing Record 17 of Set 7 | flying fish cove
# Processing Record 18 of Set 7 | qarauyl
# Processing Record 19 of Set 7 | basirpur
# Processing Record 20 of Set 7 | rio grande
# Processing Record 21 of Set 7 | takamaka
# City not found. Skipping...
# Processing Record 22 of Set 7 | yokadouma
# Processing Record 23 of Set 7 | extrema
# Processing Record 24 of Set 7 | fada
# Processing Record 25 of Set 7 | tazovsky
# Processing Record 26 of Set 7 | coari
# Processing Record 27 of Set 7 | berwick-upon-tweed
# Processing Record 28 of Set 7 | curanilahue
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | puerto lempira
# Processing Record 31 of Set 7 | cotoca
# Processing Record 32 of Set 7 | itaituba
# Processing Record 33 of Set 7 | pitanga
# Processing Record 34 of Set 7 | kapuskasing
# Processing Record 35 of Set 7 | arkalyk
# Processing Record 36 of Set 7 | fale old settlement
# Processing Record 37 of Set 7 | neftekumsk
# Processing Record 38 of Set 7 | praia da vitoria
# Processing Record 39 of Set 7 | monte argentario
# Processing Record 40 of Set 7 | huarmey
# Processing Record 41 of Set 7 | las tablas
# Processing Record 42 of Set 7 | merritt
# Processing Record 43 of Set 7 | skovorodino
# Processing Record 44 of Set 7 | saint-pierre
# Processing Record 45 of Set 7 | jessheim
# Processing Record 46 of Set 7 | san jose del cabo
# Processing Record 47 of Set 7 | las khorey
# Processing Record 48 of Set 7 | yuzhno-kurilsk
# Processing Record 49 of Set 7 | howard springs
# Processing Record 0 of Set 8 | itaberai
# Processing Record 1 of Set 8 | ulsteinvik
# Processing Record 2 of Set 8 | hakui
# Processing Record 3 of Set 8 | newman
# Processing Record 4 of Set 8 | maltby
# Processing Record 5 of Set 8 | carnarvon
# Processing Record 6 of Set 8 | cartagena
# Processing Record 7 of Set 8 | nuuk
# Processing Record 8 of Set 8 | sterling
# Processing Record 9 of Set 8 | nema
# Processing Record 10 of Set 8 | krasnogorskoye
# Processing Record 11 of Set 8 | grand baie
# Processing Record 12 of Set 8 | baiti
# Processing Record 13 of Set 8 | dudinka
# Processing Record 14 of Set 8 | tual
# Processing Record 15 of Set 8 | ivdel'
# Processing Record 16 of Set 8 | visby
# Processing Record 17 of Set 8 | macheng
# Processing Record 18 of Set 8 | riohacha
# Processing Record 19 of Set 8 | ibirama
# Processing Record 20 of Set 8 | sampit
# Processing Record 21 of Set 8 | morehead city
# Processing Record 22 of Set 8 | revda
# Processing Record 23 of Set 8 | khasab
# Processing Record 24 of Set 8 | bracebridge
# Processing Record 25 of Set 8 | bikenibeu village
# Processing Record 26 of Set 8 | juneau
# Processing Record 27 of Set 8 | callao
# Processing Record 28 of Set 8 | bad duben
# Processing Record 29 of Set 8 | archidona
# Processing Record 30 of Set 8 | lupane
# Processing Record 31 of Set 8 | ponta delgada
# Processing Record 32 of Set 8 | inhambane
# Processing Record 33 of Set 8 | okha
# Processing Record 34 of Set 8 | midvagur
# Processing Record 35 of Set 8 | wynyard
# Processing Record 36 of Set 8 | chengdu
# Processing Record 37 of Set 8 | vadso
# Processing Record 38 of Set 8 | hirara
# Processing Record 39 of Set 8 | bure
# Processing Record 40 of Set 8 | fort bragg
# Processing Record 41 of Set 8 | elkins
# Processing Record 42 of Set 8 | new norfolk
# Processing Record 43 of Set 8 | shangri-la
# City not found. Skipping...
# Processing Record 44 of Set 8 | klaksvik
# Processing Record 45 of Set 8 | selcetta
# Processing Record 46 of Set 8 | san lawrenz
# Processing Record 47 of Set 8 | jiuquan
# Processing Record 48 of Set 8 | sault ste. marie
# Processing Record 49 of Set 8 | aral
# Processing Record 0 of Set 9 | jamestown
# Processing Record 1 of Set 9 | crane
# Processing Record 2 of Set 9 | saratamata
# City not found. Skipping...
# Processing Record 3 of Set 9 | karratha
# Processing Record 4 of Set 9 | laojunmiao
# Processing Record 5 of Set 9 | bukama
# Processing Record 6 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 7 of Set 9 | saint-philippe
# Processing Record 8 of Set 9 | peniche
# Processing Record 9 of Set 9 | mossel bay
# Processing Record 10 of Set 9 | ribeira brava
# Processing Record 11 of Set 9 | knyaze-volkonskoye
# Processing Record 12 of Set 9 | aq qayeh
# City not found. Skipping...
# Processing Record 13 of Set 9 | sinabang
# Processing Record 14 of Set 9 | medina
# Processing Record 15 of Set 9 | beloyarskiy
# Processing Record 16 of Set 9 | genhe
# Processing Record 17 of Set 9 | arauquita
# Processing Record 18 of Set 9 | kaluga
# Processing Record 19 of Set 9 | mana
# Processing Record 20 of Set 9 | kalix
# Processing Record 21 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 22 of Set 9 | swakopmund
# Processing Record 23 of Set 9 | andilamena
# Processing Record 24 of Set 9 | labrador city
# Processing Record 25 of Set 9 | atbara
# Processing Record 26 of Set 9 | soio
# Processing Record 27 of Set 9 | xiuyan
# Processing Record 28 of Set 9 | puerto colombia
# Processing Record 29 of Set 9 | fort st. john
# Processing Record 30 of Set 9 | ola
# Processing Record 31 of Set 9 | chasiv yar
# Processing Record 32 of Set 9 | mahdia
# Processing Record 33 of Set 9 | hunucma
# Processing Record 34 of Set 9 | santa ana de yacuma
# Processing Record 35 of Set 9 | shingu
# Processing Record 36 of Set 9 | lesnoy
# Processing Record 37 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 9 | port alfred
# Processing Record 39 of Set 9 | dalandzadgad
# Processing Record 40 of Set 9 | novohrad-volynskyi
# Processing Record 41 of Set 9 | urzhar
# Processing Record 42 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 43 of Set 9 | phan rang-thap cham
# Processing Record 44 of Set 9 | weyburn
# Processing Record 45 of Set 9 | rongelap
# Processing Record 46 of Set 9 | lazaro cardenas
# Processing Record 47 of Set 9 | kailua-kona
# Processing Record 48 of Set 9 | peace river
# Processing Record 49 of Set 9 | mweka
# Processing Record 0 of Set 10 | pittsfield
# Processing Record 1 of Set 10 | ventersburg
# Processing Record 2 of Set 10 | grand falls-windsor
# Processing Record 3 of Set 10 | cranbrook
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | kenora
# Processing Record 6 of Set 10 | quellon
# Processing Record 7 of Set 10 | ust'-kut
# Processing Record 8 of Set 10 | megion
# Processing Record 9 of Set 10 | la'ie
# Processing Record 10 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 11 of Set 10 | cabedelo
# Processing Record 12 of Set 10 | taltal
# Processing Record 13 of Set 10 | robertsport
# Processing Record 14 of Set 10 | nadym
# Processing Record 15 of Set 10 | jiangyou
# Processing Record 16 of Set 10 | ouarzazat
# Processing Record 17 of Set 10 | languyan
# Processing Record 18 of Set 10 | vanimo
# Processing Record 19 of Set 10 | najran
# Processing Record 20 of Set 10 | duba
# Processing Record 21 of Set 10 | kalabo
# Processing Record 22 of Set 10 | buala
# Processing Record 23 of Set 10 | qarazhal
# Processing Record 24 of Set 10 | caldas novas
# Processing Record 25 of Set 10 | inza
# Processing Record 26 of Set 10 | acarau
# Processing Record 27 of Set 10 | sinop
# Processing Record 28 of Set 10 | asau village
# City not found. Skipping...
# Processing Record 29 of Set 10 | ngaoundere
# Processing Record 30 of Set 10 | gaspe
# Processing Record 31 of Set 10 | manta
# Processing Record 32 of Set 10 | athens
# Processing Record 33 of Set 10 | geraldton
# Processing Record 34 of Set 10 | coahuayana de hidalgo
# Processing Record 35 of Set 10 | aasiaat
# Processing Record 36 of Set 10 | plettenberg bay
# Processing Record 37 of Set 10 | mar del plata
# Processing Record 38 of Set 10 | turpan
# Processing Record 39 of Set 10 | kruisfontein
# Processing Record 40 of Set 10 | niamey
# Processing Record 41 of Set 10 | poronaysk
# Processing Record 42 of Set 10 | argo
# Processing Record 43 of Set 10 | baskale
# Processing Record 44 of Set 10 | bodo
# Processing Record 45 of Set 10 | greenville
# Processing Record 46 of Set 10 | choyr
# Processing Record 47 of Set 10 | langxiang
# Processing Record 48 of Set 10 | sinjai
# Processing Record 49 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 0 of Set 11 | ingeniero guillermo n. juarez
# Processing Record 1 of Set 11 | holualoa
# Processing Record 2 of Set 11 | hell-ville
# Processing Record 3 of Set 11 | dikwa
# Processing Record 4 of Set 11 | saint-joseph
# Processing Record 5 of Set 11 | la foa
# Processing Record 6 of Set 11 | bayji
# Processing Record 7 of Set 11 | chicxulub puerto
# City not found. Skipping...
# Processing Record 8 of Set 11 | newark
# Processing Record 9 of Set 11 | boende
# Processing Record 10 of Set 11 | ratanpur
# Processing Record 11 of Set 11 | dapa
# Processing Record 12 of Set 11 | obsharovka
# Processing Record 13 of Set 11 | newnham
# Processing Record 14 of Set 11 | iwanai
# Processing Record 15 of Set 11 | zinjibar
# Processing Record 16 of Set 11 | ji'an
# Processing Record 17 of Set 11 | santa cruz
# Processing Record 18 of Set 11 | kaoma
# Processing Record 19 of Set 11 | kisangani
# Processing Record 20 of Set 11 | sarykemer
# Processing Record 21 of Set 11 | isiro
# Processing Record 22 of Set 11 | narvik
# Processing Record 23 of Set 11 | bich'vinta
# Processing Record 24 of Set 11 | nikolayevsk-on-amure
# Processing Record 25 of Set 11 | camana
# Processing Record 26 of Set 11 | banda aceh
# Processing Record 27 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 11 | itamaraca
# Processing Record 29 of Set 11 | prince rupert
# Processing Record 30 of Set 11 | laminusa
# Processing Record 31 of Set 11 | tra mhor
# Processing Record 32 of Set 11 | nicoya
# Processing Record 33 of Set 11 | deir ez-zor
# Processing Record 34 of Set 11 | nadi
# Processing Record 35 of Set 11 | la passe
# Processing Record 36 of Set 11 | lorengau
# Processing Record 37 of Set 11 | wajir
# Processing Record 38 of Set 11 | stornoway
# Processing Record 39 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 40 of Set 11 | ulladulla
# Processing Record 41 of Set 11 | mtwara
# Processing Record 42 of Set 11 | manokwari
# Processing Record 43 of Set 11 | otuzco
# Processing Record 44 of Set 11 | ajaccio
# Processing Record 45 of Set 11 | kone
# Processing Record 46 of Set 11 | salinas de hidalgo
# Processing Record 47 of Set 11 | pangoa
# Processing Record 48 of Set 11 | nova sintra
# Processing Record 49 of Set 11 | costa teguise
# City not found. Skipping...
# Processing Record 0 of Set 12 | puerto santa
# Processing Record 1 of Set 12 | cimin
# Processing Record 2 of Set 12 | barakani
# Processing Record 3 of Set 12 | padang
# Processing Record 4 of Set 12 | arkhangel'sk
# Processing Record 5 of Set 12 | al ghayzah
# Processing Record 6 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 7 of Set 12 | inekar
# City not found. Skipping...
# Processing Record 8 of Set 12 | novo aripuana
# Processing Record 9 of Set 12 | jaffna
# Processing Record 10 of Set 12 | mitsamiouli
# Processing Record 11 of Set 12 | olyokminsk
# Processing Record 12 of Set 12 | yemva
# Processing Record 13 of Set 12 | pindushi
# Processing Record 14 of Set 12 | pemangkat
# Processing Record 15 of Set 12 | hede
# Processing Record 16 of Set 12 | pyoksong-up
# Processing Record 17 of Set 12 | bolvadin
# Processing Record 18 of Set 12 | hotan
# Processing Record 19 of Set 12 | mahina
# Processing Record 20 of Set 12 | quepos
# Processing Record 21 of Set 12 | pitkyaranta
# Processing Record 22 of Set 12 | port townsend
# Processing Record 23 of Set 12 | taoudenni
# Processing Record 24 of Set 12 | herceg novi
# Processing Record 25 of Set 12 | kargopol'
# Processing Record 26 of Set 12 | brigantine
# Processing Record 27 of Set 12 | yelizovo
# Processing Record 28 of Set 12 | astravyets
# Processing Record 29 of Set 12 | agapovka
# Processing Record 30 of Set 12 | songyuan
# Processing Record 31 of Set 12 | qamdo
# Processing Record 32 of Set 12 | saint-denis
# Processing Record 33 of Set 12 | sao joao da barra
# Processing Record 34 of Set 12 | isla mujeres
# Processing Record 35 of Set 12 | aitape
# Processing Record 36 of Set 12 | nago
# Processing Record 37 of Set 12 | turtas
# Processing Record 38 of Set 12 | outjo
# Processing Record 39 of Set 12 | colonia
# Processing Record 40 of Set 12 | khilok
# Processing Record 41 of Set 12 | lowestoft
# Processing Record 42 of Set 12 | mhamid
# Processing Record 43 of Set 12 | tazacorte
# Processing Record 44 of Set 12 | krasnogorskiy
# Processing Record 45 of Set 12 | puerto penasco
# Processing Record 46 of Set 12 | khamis mushait
# Processing Record 47 of Set 12 | port lincoln
# Processing Record 48 of Set 12 | cururupu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   grytviken -54.2811  -36.5092      2.08        91         100       12.39
# 1    waitangi -43.9535 -176.5597     16.01        88           0        0.89
# 2  constantia  44.1833   28.6500      7.61        64          29        4.00
# 3     renfrew  55.8720   -4.3925     11.75        90         100        2.57
# 4    kuraymah  18.5500   31.8500     22.18        14          29        4.50
#
#   Country        Date
# 0      GS  1682905996
# 1      NZ  1682905997
# 2      RO  1682905997
# 3      GB  1682905997
# 4      SD  1682905997

# %%
# Check if directory exists, if not, make new directory
if not os.path.exists("Output_data"):
    os.mkdir("Output_data")
    output_path = os.path.join(os.getcwd(),'WeatherPy','Output_data')
    print("Created directory" + output_path)
else:
    output_path = os.path.join(os.getcwd(),'WeatherPy','Output_data')
    print(f"{output_path} directory already exists")
 
# Export the City_Data into a csv
city_data_df.to_csv("Output_data/cities.csv", index_label="City_ID")
# Out:
# Created directory/Users/michaelnaffziger/Desktop/Homework UO Bootcamp/python-api-challenge/WeatherPy/WeatherPy/Output_data

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         grytviken -54.2811  -36.5092      2.08        91         100
# 1          waitangi -43.9535 -176.5597     16.01        88           0
# 2        constantia  44.1833   28.6500      7.61        64          29
# 3           renfrew  55.8720   -4.3925     11.75        90         100
# 4          kuraymah  18.5500   31.8500     22.18        14          29
#
#          Wind Speed Country        Date
# City_ID
# 0             12.39      GS  1682905996
# 1              0.89      NZ  1682905997
# 2              4.00      RO  1682905997
# 3              2.57      GB  1682905997
# 4              4.50      SD  1682905997

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
#Create a date stamp for when plot was generated
import datetime
now = datetime.datetime.now()
date_string = now.strftime("%Y-%m-%d")


# Reading on, I noticed this got VERY repeatitive, so I made a function to the repeativite tasks
def city_scatter(city_data_df, y_col):
    
    # Originally I had the y_axis data and labe as input() strings...
    # but it got too annoying, so I hardcoded them for this assignment
    y_axis_complete = f"{y_axis_title} {y_axis_units}"
    plt.scatter(
        city_data_df["Lat"],
        city_data_df[y_col],
        edgecolors='black',
        marker= "o",
        alpha= 0.5,
        label = "Cities"
    )
    plt.ylabel(y_axis_complete)
    plt.xlabel("Latitude")
    plt.grid(True)
    plt.title(f"City Max Latitude vs. {y_axis_title} ({date_string})")

    plt.savefig(f"output_data/Fig{fig_num} City {y_col} {date_string}.png")

    plt.show()

y_col = "Max Temp"
y_axis_units = "(°C)"
y_axis_title = "Max Temperature"
fig_num = "1"
city_scatter(city_data_df,y_col)

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# # Build the scatter plots for latitude vs. humidity

y_col = "Humidity"
y_axis_units = "(%)"
y_axis_title = "Humidity"
fig_num = "2"
city_scatter(city_data_df,y_col)

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# # Build the scatter plots for latitude vs. cloudiness
y_col = "Cloudiness"
y_axis_units = "(%)"
y_axis_title = "Cloudiness"
fig_num = "3"
city_scatter(city_data_df,y_col)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_col = "Wind Speed"
y_axis_units = "(m/s)"
y_axis_title = "Wind Speed"
fig_num = "4"
city_scatter(city_data_df,y_col)

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

## SO NOW you want me to create a function... i see :)
def hemi_city_scatter(hemi_df, y_col):
    y_axis_complete = f"{y_axis_title} {y_axis_units}"
    
    # Create variables for linear regression equation to print onto plot
    (slope, intercept, rvalue, pvalue, stderr) = linregress(hemi_df['Lat'],hemi_df[y_col])
    y_values = hemi_df['Lat']*slope + intercept
    line_eq= f" y = {round(slope,2)}x + {round(intercept,2)}"
    r_squarred = str(round(rvalue**2,8))
    
    #make plot
    plt.scatter(
        hemi_df['Lat'],
        hemi_df[y_col],
        edgecolors='black',
        marker= "o",
        alpha= 0.5,
        label = "Cities" 
    )
    #Regression line 
    plt.plot(hemi_df['Lat'],y_values,color='red')
    plt.annotate(line_eq,(place),fontsize=12,color="red")
    
    #Label formatting
    plt.ylabel(y_axis_complete)
    plt.xlabel("Latitude")
    plt.grid(True)
    plt.title(f"{Hemisphere} Hemisphere City Max Latitude vs. {y_axis_title} ({date_string})")
    
    plt.savefig(f"output_data/Fig{fig_num} {Hemisphere}-hemi {y_col} {date_string}.png")

    plt.show()
    print(f"The r-value is {r_squarred}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           constantia  44.1833   28.6500      7.61        64          29
# 3              renfrew  55.8720   -4.3925     11.75        90         100
# 4             kuraymah  18.5500   31.8500     22.18        14          29
# 5        wang sai phun  16.3885  100.5380     33.23        49          10
# 6                horta  38.5333  -28.6333     16.12        78           3
#
#          Wind Speed Country        Date
# City_ID
# 2              4.00      RO  1682905997
# 3              2.57      GB  1682905997
# 4              4.50      SD  1682905997
# 5              1.12      TH  1682905998
# 6              8.94      PT  1682905716

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] <=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             grytviken -54.2811  -36.5092      2.08        91         100
# 1              waitangi -43.9535 -176.5597     16.01        88           0
# 7          punta arenas -53.1500  -70.9167      7.06        70          75
# 10       puerto natales -51.7236  -72.4875      5.99        82          96
# 11        alice springs -23.7000  133.8833     18.75        34          66
#
#          Wind Speed Country        Date
# City_ID
# 0             12.39      GS  1682905996
# 1              0.89      NZ  1682905997
# 7             13.38      CL  1682905868
# 10             7.40      CL  1682905999
# 11             3.09      AU  1682905999

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
hemi_df = northern_hemi_df
Hemisphere = "N"
y_col = "Max Temp"
y_axis_units = "(°C)"
y_axis_title = "Max Temperature"
fig_num = "1"
place =(0,-5)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.74615925

# %%
# Linear regression on Southern Hemisphere
hemi_df = southern_hemi_df
Hemisphere = "S"
y_col = "Max Temp"
y_axis_units = "(°C)"
y_axis_title = "Max Temperature"
fig_num = "1"
place =(-30,5)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.57650763

# %% [markdown]
# ## **Discussion about the linear relationship:**
#
# - There is a corresponding relationship between distance from the equator and the max temperature recorded
# - There are more cities represented in the northern hemisphere, providing a tighter r-value

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
hemi_df = northern_hemi_df
Hemisphere = "N"
y_col = "Humidity"
y_axis_units = "(%)"
y_axis_title = "Relative Humidity"
fig_num = "2"
place =(50,10)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.00490331

# %%
# Southern Hemisphere
hemi_df = southern_hemi_df
Hemisphere = "S"
y_col = "Humidity"
y_axis_units = "(%)"
y_axis_title = "Relative Humidity"
fig_num = "2"
place =(50,10)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.00963526

# %% [markdown]
# ## **Discussion about the linear relationship:**
# - There does not seem to be a tight relationship between a hemisphere's humidity and latitude
# - This is most litely due to the humidity being recorded as relative humidity and not absolute.  Relative humidy only represents how mush water vapor the air can hold.  This is dependant on temperature, the warmer the air, the more water vapor it can hold.
# - The humidity plots, however, do suggest that cities closer to the equator are hotter than cities closer to the poles.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
hemi_df = northern_hemi_df
Hemisphere = "N"
y_col = "Cloudiness"
y_axis_units = "(%)"
y_axis_title = "Cloudiness"
fig_num = "3"
place =(55,30)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.00058848

# %%
# Southern Hemisphere
hemi_df = southern_hemi_df
Hemisphere = "S"
y_col = "Cloudiness"
y_axis_units = "(%)"
y_axis_title = "Cloudiness"
fig_num = "3"
place =(-55,20)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.03250192

# %% [markdown]
# ## **Discussion about the linear relationship:**
#
# - There is a weak but positive relationship between cloudiness and latitude
# - These charts show that the cloudiest areas are located near the equator and closer to the artic/antartic circles
# - Locations with the least amount of cloudy days are between 30° and 40° above the equator.
# - This trend can be explained by typical atmospheric water quantities.  At the extremes, there are either either hot humid water vapor mixing with cold regional temps, or cold air mixing with hot humid air: both of these situations will produce clouds, and generate weather events.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
hemi_df = northern_hemi_df
Hemisphere = "N"
y_col = "Wind Speed"
y_axis_units = "(m/s)"
y_axis_title = "Wind Speed"
fig_num = "4"
place =(0,10)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.01324875

# %%
# Southern Hemisphere
hemi_df = southern_hemi_df
Hemisphere = "S"
y_col = "Wind Speed"
y_axis_units = "(m/s)"
y_axis_title = "Wind Speed"
fig_num = "4"
place =(-30,10)
hemi_city_scatter(hemi_df, y_col)
# Out:
# The r-value is 0.06030105

# %% [markdown]
# ## **Discussion about the linear relationship:**
#
# Though there is a weak relationship observed between the wind speed and latitude, a couple of observations can be concluded:
# - The northern hemishpere has more land above sea level than the southern hemisphere.  This affects windspeeds not only by topography, but also by the difference in land and water caputuring and holding onto heat from the sun.  This dynamic is the cause of wind, and fuels the high and low pressure zones.
# - When the outliers are -roughly- removed from the plots by inspection (lostly the reported wind speed above 7 m/s), the general trend is that the farther from the equator you are, the higher the wind speeds will be.
# - The high variability of the northern hemisphere vs the southern hemisphere can be related to more above sea level mass.  Since the southern hemisphere has more water, it can regulate a steadier temperature, and does not interact as must with the land absorbing/releasing heat as much- therefore providing a tighter grouping than the northern hemisphere data.
