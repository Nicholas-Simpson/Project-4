# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, classification_report

# %%
# ID feature is already dropped from cleaning notebook
# Define the paths for all source files
cwd = os.getcwd()
orig_test_data_path = os.path.join(cwd,'wine_data','test.csv')
orig_train_data_path = os.path.join(cwd,'wine_data','train.csv')

# Open all source files as a pd dataframe
orig_test = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/test.csv')
orig_train = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/train.csv')
red_data = pd.read_csv('red_data_noID.csv')
white_data = pd.read_csv('white_data_noID.csv')
red_white_data = pd.read_csv('red_white_data_noID.csv')
trainable_data = pd.read_csv('trainable_data_noID.csv')

# Drop 'ID' columns
orig_test = orig_test.drop(columns='Id')
orig_train = orig_train.drop(columns='Id')

# %%
# Split the data into training and testing sets
X_train_all = trainable_data.drop('quality', axis=1)
y_train_all = trainable_data['quality'].copy()
X_test_all = trainable_data.copy()
# y_test_all -= 3
X_train_all, X_val_all, y_train_all, y_val_all = train_test_split(X_train_all, 
                                                  y_train_all, 
                                                  test_size = 0.2, 
                                                  random_state = 42) #because it is the answer :)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# Create a Gradient Boosting Regressor
all_model = GradientBoostingClassifier()

# Define the hyperparameter grid to search
all_param_grid = {
    'n_estimators': [50, 100, 200], # number of weak learning trees
    'learning_rate': [0.01, 0.1, 0.2], # control possibility of overfitting.
    # Strong interaction with n_estimators: smaller learning rates require more n_estimators
    'max_depth': [3, 5, 7] #  size of each tree
}

# Perform grid search with cross-validation
all_grid_search = GridSearchCV(all_model, all_param_grid, cv=5, verbose=3)
all_grid_search.fit(X_train_all, y_train_all)

# Get the best model from grid search
all_best_gb = all_grid_search.best_estimator_

# Make predictions on the test data using the best model
y_pred_all = all_best_gb.predict(X_val_all)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.519 total time=   3.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.541 total time=   3.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.535 total time=   3.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.548 total time=   3.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.536 total time=   3.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.530 total time=   6.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.560 total time=   6.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.543 total time=   6.8s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.556 total time=   6.5s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.550 total time=   6.5s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.551 total time=  13.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.576 total time=  12.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.560 total time=  12.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.566 total time=  13.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.558 total time=  12.9s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.538 total time=   5.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.563 total time=   5.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.545 total time=   5.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.558 total time=   5.4s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.565 total time=   5.4s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.554 total time=  10.5s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.581 total time=  10.6s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.567 total time=  11.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.575 total time=  10.7s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.580 total time=  10.6s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.571 total time=  21.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.608 total time=  20.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.586 total time=  20.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.587 total time=  21.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.585 total time=  20.5s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.554 total time=   7.6s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.584 total time=   7.5s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.575 total time=   7.6s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.575 total time=   7.5s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.582 total time=   7.5s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.578 total time=  15.8s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.610 total time=  15.8s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.598 total time=  15.0s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.589 total time=  15.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.599 total time=  15.0s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.609 total time=  30.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.638 total time=  29.7s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.612 total time=  30.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.599 total time=  30.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.607 total time=  31.6s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.548 total time=   3.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.600 total time=   3.1s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.571 total time=   3.3s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.558 total time=   3.3s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.567 total time=   3.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.571 total time=   6.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.613 total time=   6.6s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.585 total time=   6.4s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.570 total time=   6.3s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.580 total time=   6.4s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.580 total time=  12.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.625 total time=  13.1s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.594 total time=  12.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.581 total time=  12.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.577 total time=  12.9s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.589 total time=   5.3s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.622 total time=   5.4s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.588 total time=   5.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.591 total time=   5.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.597 total time=   5.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.611 total time=  10.7s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.640 total time=  10.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.605 total time=  11.3s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.588 total time=  10.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.614 total time=  10.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.622 total time=  19.7s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.650 total time=  19.9s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.618 total time=  19.7s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.613 total time=  19.8s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.624 total time=  19.1s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.626 total time=   7.5s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.639 total time=   7.5s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.617 total time=   7.6s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.603 total time=   7.7s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.633 total time=   7.9s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.624 total time=  15.7s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.641 total time=  15.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.630 total time=  15.0s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.606 total time=  14.9s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.633 total time=  15.0s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.622 total time=  28.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.641 total time=  28.2s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.629 total time=  29.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.626 total time=  28.7s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.634 total time=  28.5s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.562 total time=   3.2s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.608 total time=   3.2s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.576 total time=   3.2s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.575 total time=   3.2s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.558 total time=   4.4s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.576 total time=   6.6s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.619 total time=   6.3s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.585 total time=   6.4s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.575 total time=   6.4s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.581 total time=   6.1s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.584 total time=  13.9s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.622 total time=  13.0s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.586 total time=  13.0s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.591 total time=  12.9s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.582 total time=  12.9s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.592 total time=   5.1s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.626 total time=   5.3s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.604 total time=   6.4s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.594 total time=   5.8s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.599 total time=   5.5s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.619 total time=  10.2s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.633 total time=   9.7s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.607 total time=  10.1s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.608 total time=  10.0s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.614 total time=  10.4s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.625 total time=  18.9s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.649 total time=  19.3s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.616 total time=  18.5s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.613 total time=  18.9s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.626 total time=  19.3s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.619 total time=   7.9s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.634 total time=   8.4s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.605 total time=   7.6s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.599 total time=   7.5s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.625 total time=   8.1s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.619 total time=  14.1s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.641 total time=  14.7s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.618 total time=  14.6s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.617 total time=  14.1s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.633 total time=  14.5s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.619 total time=  25.0s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.645 total time=  25.1s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.617 total time=  25.3s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.622 total time=  26.6s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.632 total time=  26.7s

# %%
# Calculate metrics
all_accuracy = accuracy_score(y_val_all, y_pred_all)
# the following metrics need to include the average type since the validation is ordinal and not binary
all_f1 = f1_score(y_val_all, y_pred_all, average= 'weighted')
all_precision = precision_score(y_val_all, y_pred_all, average= 'weighted')
all_recall = recall_score(y_val_all, y_pred_all, average= 'weighted')

print(f"Best Estimators: {all_best_gb.n_estimators}")
print(f"Best Learning Rate: {all_best_gb.learning_rate}")
print(f"Best Max Depth: {all_best_gb.max_depth}")
print(f"Accuracy: {all_accuracy:.2f}")
print(f"F1: {all_f1:.2f}")
print(f"Precision: {all_precision:.2f}")
print(f"Recall: {all_recall:.2f}")
# Out:
# Best Estimators: 200
# Best Learning Rate: 0.1
# Best Max Depth: 7
# Accuracy: 0.65
# F1: 0.64
# Precision: 0.65
# Recall: 0.65

# %%
# Create a Gradient Boosting Regressor
all_model_2 = GradientBoostingClassifier()

# Define the hyperparameter grid to search
all_param_grid_2 = {
    'n_estimators': [100, 200, 400], # number of weak learning trees
    'learning_rate': [0.01, 0.1, 0.2], # control possibility of overfitting.
    # Strong interaction with n_estimators: smaller learning rates require more n_estimators
    'max_depth': [5, 7, 9] #  size of each tree
}

# Perform grid search with cross-validation
all_grid_search_2 = GridSearchCV(all_model_2, all_param_grid_2, cv=5, verbose=3)
all_grid_search_2.fit(X_train_all, y_train_all)

# Get the best model from grid search
all_best_gb_2 = all_grid_search_2.best_estimator_

# Make predictions on the test data using the best model
y_pred_all_2 = all_best_gb_2.predict(X_val_all)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.554 total time=  10.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.581 total time=  10.4s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.567 total time=  10.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.575 total time=  11.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.580 total time=  10.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.571 total time=  20.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0

# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=200;, score=0.632 total time=  32.3s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=200;, score=0.630 total time=  32.7s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=400;, score=0.621 total time=  46.0s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=400;, score=0.637 total time=  45.3s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=400;, score=0.629 total time=  45.5s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=400;, score=0.624 total time=  45.7s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=400;, score=0.636 total time=  46.2s

# %%
# Calculate metrics
all_accuracy_2 = accuracy_score(y_val_all, y_pred_all_2)
# the following metrics need to include the average type since the validation is ordinal and not binary
all_f1_2 = f1_score(y_val_all, y_pred_all_2, average= 'weighted')
all_precision_2 = precision_score(y_val_all, y_pred_all_2, average= 'weighted')
all_recall_2 = recall_score(y_val_all, y_pred_all_2, average= 'weighted')

print(f"Best Estimators: {all_best_gb_2.n_estimators}")
print(f"Best Learning Rate: {all_best_gb_2.learning_rate}")
print(f"Best Max Depth: {all_best_gb_2.max_depth}")
print(f"Accuracy: {all_accuracy_2:.2f}")
print(f"F1: {all_f1_2:.2f}")
print(f"Precision: {all_precision_2:.2f}")
print(f"Recall: {all_recall_2:.2f}")
# Out:
# Best Estimators: 400
# Best Learning Rate: 0.01
# Best Max Depth: 9
# Accuracy: 0.66
# F1: 0.65
# Precision: 0.66
# Recall: 0.66

# %%
all_best_hp = all_grid_search.best_params_
print(f"Best hp for 1st model: {all_best_hp}")
print("---------------------------------")
print("Confusion Matrix:")
display(confusion_matrix(y_val_all, y_pred_all))
print("---------------------------------")
print(classification_report(y_val_all,y_pred_all))
# Out:
# Best hp for 1st model: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
# ---------------------------------
# Confusion Matrix:
# array([[  0,   0,   4,   1,   0,   0,   0],
#        [  3,   7,  30,  14,   1,   0,   0],
#        [  4,   3, 418, 150,   7,   0,   0],
#        [  2,   2, 154, 529,  49,   1,   0],
#        [  0,   0,  15, 129, 131,   3,   1],
#        [  0,   0,   1,  20,  12,  20,   0],
#        [  0,   0,   0,   0,   0,   0,   0]])
# ---------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.58      0.13      0.21        55
#            5       0.67      0.72      0.69       582
#            6       0.63      0.72      0.67       737
#            7       0.66      0.47      0.55       279
#            8       0.83      0.38      0.52        53
#            9       0.00      0.00      0.00         0
#
#     accuracy                           0.65      1711
#    macro avg       0.48      0.34      0.38      1711
# weighted avg       0.65      0.65      0.64      1711

# %%
all_best_hp_2 = all_grid_search_2.best_params_
print(f"Best hp for 2nd model: {all_best_hp_2}")
print("---------------------------------")
print("Confusion Matrix:")
display(confusion_matrix(y_val_all, y_pred_all_2))
print("---------------------------------")
print(classification_report(y_val_all,y_pred_all_2))
# Out:
# Best hp for 2nd model: {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 400}
# ---------------------------------
# Confusion Matrix:
# array([[  0,   0,   3,   2,   0,   0,   0],
#        [  0,   8,  32,  15,   0,   0,   0],
#        [  1,   3, 430, 142,   6,   0,   0],
#        [  0,   2, 151, 527,  55,   2,   0],
#        [  0,   0,  11, 126, 138,   3,   1],
#        [  0,   0,   1,  18,  13,  21,   0],
#        [  0,   0,   0,   0,   0,   0,   0]])
# ---------------------------------
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.62      0.15      0.24        55
#            5       0.68      0.74      0.71       582
#            6       0.63      0.72      0.67       737
#            7       0.65      0.49      0.56       279
#            8       0.81      0.40      0.53        53
#            9       0.00      0.00      0.00         0
#
#     accuracy                           0.66      1711
#    macro avg       0.48      0.36      0.39      1711
# weighted avg       0.66      0.66      0.65      1711
