# %% [markdown]
# # Gradient Boosting Classifier Model
# ---
# The model in this notebook was strongly influenced by Natural Chan.  The following gradient boosted classifier will be used in an ordinal regression dataset.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, cohen_kappa_score

import time

from warnings import filterwarnings
filterwarnings('ignore')

# %%
# from kappa_score import qwkappa

# %%
# The 'ID' feature is already dropped from cleaning notebook

# Open all source files as a pd dataframe
# This dataset will be used to train the gradient boosted model
orig_train = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/train.csv')

#This dataset will be used to evaluate again the Kaggle compitition entry submission
orig_test = pd.read_csv('https://project4-wine-quality-2023.s3.us-west-2.amazonaws.com/test.csv')

# Addition datasets to explore the GradBoost model on actual wine data
red_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/Michael/red_white_data_noID.csv')
white_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/Michael/white_data_noID.csv')
red_white_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/Michael/red_white_data_noID.csv')
trainable_data = pd.read_csv('https://raw.githubusercontent.com/Nicholas-Simpson/Project-4/main/Michael/trainable_data_noID.csv')

# Drop 'ID' columns
orig_test = orig_test.drop(columns='Id')
orig_train = orig_train.drop(columns='Id')

# Create a place to save any generated files
gb_output_path = os.path.join(os.getcwd(),'grad boost output')
os.makedirs(gb_output_path, exist_ok = True)

# %%
# Split the data into training and testing sets
X_train = orig_train.drop('quality', axis=1)
y_train = orig_train['quality'].copy()
X_test = orig_test.copy()
X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                  y_train, 
                                                  test_size = 0.2, 
                                                  random_state = 42) #because it is the answer :)

# %%
# Create a Gradient Boosting Regressor
model = GradientBoostingClassifier()

# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200], # number of weak learning trees
    'learning_rate': [0.01, 0.1, 0.2], # control possibility of overfitting.
    # Strong interaction with n_estimators: smaller learning rates require more n_estimators
    'max_depth': [3, 5, 7] #  size of each tree
}

# Perform grid search with cross-validation, mark timer start
start_time = time.time()
grid_search = GridSearchCV(model, param_grid, cv=5, verbose=3)
grid_search.fit(X_train, y_train)

# Get the best model from grid search
best_gb = grid_search.best_estimator_
grid_search_time = time.time()

# Make predictions on the test data using the best model
y_pred = best_gb.predict(X_val)

# Report how long it took to complete Grid search and prediction
end_time = time.time()
grid_time = grid_search_time - start_time
pred_time = end_time - grid_search_time
tot_time = end_time - start_time

print(f"Time to complete Grid Search: {grid_time:.6f} seconds")
print(f"Time to complete prediction: {pred_time:.6f} seconds")
print(f"Total time to complete Grid Search and prediction: {tot_time:.6f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.556 total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.578 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.596 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.565 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.588 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.568 total time=   1.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.587 total time=   1.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.611 total time=   1.8s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.574 total time=   1.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.591 total time=   2.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.553 total time=   3.8s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.6s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.611 total time=   3.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.599 total time=   4.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.598 total time=   3.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.584 total time=   1.5s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.581 total time=   1.5s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.587 total time=   1.5s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.581 total time=   1.5s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=0.573 total time=   1.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.559 total time=   2.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.584 total time=   2.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.596 total time=   2.9s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.571 total time=   2.9s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=0.613 total time=   2.9s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.541 total time=   5.8s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.544 total time=   5.8s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.605 total time=   5.7s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.578 total time=   5.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.579 total time=   5.8s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.574 total time=   2.3s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.547 total time=   2.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.587 total time=   2.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.529 total time=   2.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=0.588 total time=   2.3s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.565 total time=   4.5s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.544 total time=   4.5s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.584 total time=   4.5s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.538 total time=   4.6s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=0.570 total time=   4.6s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.559 total time=   9.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.547 total time=   9.4s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.574 total time=   9.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.578 total time=   9.2s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.579 total time=   9.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.565 total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.550 total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.605 total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.602 total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.579 total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.556 total time=   1.8s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.547 total time=   1.8s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.593 total time=   1.8s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.578 total time=   1.8s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.579 total time=   1.8s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.550 total time=   3.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.538 total time=   3.5s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.587 total time=   3.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.559 total time=   3.6s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.570 total time=   3.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.559 total time=   1.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.562 total time=   1.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.593 total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.581 total time=   1.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.585 total time=   1.5s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.559 total time=   3.4s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.541 total time=   3.2s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.584 total time=   3.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.596 total time=   2.9s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.582 total time=   2.9s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.541 total time=   5.7s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.526 total time=   5.8s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.593 total time=   5.7s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.578 total time=   5.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.570 total time=   5.7s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.544 total time=   2.3s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.538 total time=   2.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.565 total time=   2.6s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.593 total time=   2.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=0.564 total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.550 total time=   4.6s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.544 total time=   4.6s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.596 total time=   4.7s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.568 total time=   4.6s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=0.579 total time=   4.7s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.556 total time=   9.1s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.553 total time=   9.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.584 total time=   9.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.587 total time=   9.0s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.591 total time=   9.0s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.535 total time=   0.9s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.544 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.602 total time=   0.9s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.581 total time=   0.9s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.549 total time=   0.9s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.553 total time=   1.9s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.529 total time=   1.8s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.605 total time=   1.8s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.562 total time=   1.8s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.561 total time=   1.8s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.547 total time=   3.5s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.526 total time=   3.5s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.593 total time=   3.5s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.541 total time=   3.5s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=200;, score=0.573 total time=   3.7s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.535 total time=   1.6s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.520 total time=   1.5s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.565 total time=   1.6s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.556 total time=   1.5s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.579 total time=   1.5s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.532 total time=   2.9s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.535 total time=   2.9s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.587 total time=   2.9s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.565 total time=   2.9s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.561 total time=   3.1s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.541 total time=   5.7s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.523 total time=   5.6s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.584 total time=   5.6s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.553 total time=   5.7s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=200;, score=0.570 total time=   5.5s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.532 total time=   2.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.541 total time=   2.3s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.578 total time=   2.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.590 total time=   2.4s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=50;, score=0.582 total time=   2.4s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.544 total time=   4.4s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.523 total time=   4.4s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.578 total time=   4.4s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.584 total time=   4.5s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=100;, score=0.604 total time=   4.5s
# [CV 1/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.529 total time=   7.3s
# [CV 2/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.541 total time=   7.1s
# [CV 3/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.568 total time=   8.9s
# [CV 4/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.550 total time=   7.6s
# [CV 5/5] END learning_rate=0.2, max_depth=7, n_estimators=200;, score=0.570 total time=   7.4s
# Time to complete Grid Search: 486.561659 seconds
# Time to complete prediction: 0.010517 seconds
# Total time to complete Grid Search and prediction: 486.572176 seconds

# %%
# Calculate metrics
accuracy = accuracy_score(y_val, y_pred)
# the following metrics need to include the average type since the validation is ordinal and not binary
f1 = f1_score(y_val, y_pred, average= 'weighted')
precision = precision_score(y_val, y_pred, average= 'weighted')
recall = recall_score(y_val, y_pred, average= 'weighted')
kappa = cohen_kappa_score(y_val, y_pred, weights='quadratic')

print(f"First model scores:")
print("-------------------")
print(f"Best Estimators: {best_gb.n_estimators}")
print(f"Best Learning Rate: {best_gb.learning_rate}")
print(f"Best Max Depth: {best_gb.max_depth}")
print(f"Accuracy: {accuracy:.2f}")
print(f"F1: {f1:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Cohen Kappa Score, quadratic weighted: {kappa}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Calculate metrics
# ----> 2 accuracy = accuracy_score(y_val, y_pred)
#       3 # the following metrics need to include the average type since the validation is ordinal and not binary
#       4 f1 = f1_score(y_val, y_pred, average= 'weighted')
#
# NameError: name 'y_val' is not defined

# %%
# Change the number of weak learner trees
# Create a Gradient Boosting Regressor
model_2 = GradientBoostingClassifier()

# Define the hyperparameter grid to search
param_grid_2 = {
    'n_estimators': [200, 400,800],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [3, 5, 7]
}

# Perform grid search with cross-validation
start_time_2 = time.time()
grid_search_2 = GridSearchCV(model_2, param_grid_2, cv=5, verbose=3)
grid_search_2.fit(X_train, y_train)

# Get the best model from grid search
best_gb_2 = grid_search_2.best_estimator_
grid_search_time_2 = time.time()

# Make predictions on the test data using the best model
y_pred_2 = best_gb_2.predict(X_val)

# Report how long it took to complete Grid search and prediction
end_time_2 = time.time()
grid_time_2 = grid_search_time_2 - start_time_2
pred_time_2 = end_time_2 - grid_search_time_2
tot_time_2 = end_time_2 - start_time_2

print(f"Time to complete Grid Search: {grid_time_2:.6f} seconds")
print(f"Time to complete prediction: {pred_time_2:.6f} seconds")
print(f"Total time to complete Grid Search and prediction: {tot_time_2:.6f} seconds")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.574 total time=   3.8s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.578 total time=   3.6s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.581 total time=   3.6s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.562 total time=   3.9s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=200;, score=0.582 total time=   3.9s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.565 total time=   7.6s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.562 total time=   7.5s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.593 total time=   7.2s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.571 total time=   7.4s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=400;, score=0.579 total time=   7.2s
# [CV 1/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.562 total time=  14.1s
# [CV 2/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.584 total time=  14.2s
# [CV 3/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.611 total time=  14.3s
# [CV 4/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.574 total time=  14.9s
# [CV 5/5] END learning_rate=0.001, max_depth=3, n_estimators=800;, score=0.576 total time=  14.9s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.547 total time=   6.0s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.562 total time=   6.0s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.571 total time=   5.8s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.559 total time=   5.8s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=200;, score=0.561 total time=   5.9s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.590 total time=  11.8s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.581 total time=  11.8s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.581 total time=  11.7s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.581 total time=  12.0s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=400;, score=0.579 total time=  12.2s
# [CV 1/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.584 total time=  24.7s
# [CV 2/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.584 total time=  23.8s
# [CV 3/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.605 total time=  23.7s
# [CV 4/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.562 total time=  24.5s
# [CV 5/5] END learning_rate=0.001, max_depth=5, n_estimators=800;, score=0.591 total time=  24.3s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.520 total time=  10.0s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.538 total time=   9.7s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.544 total time=   9.3s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.541 total time=   9.5s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=200;, score=0.552 total time=   9.5s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.568 total time=  18.4s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.541 total time=  18.9s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.593 total time=  18.5s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.532 total time=  18.9s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=400;, score=0.576 total time=  19.0s
# [CV 1/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.581 total time=  37.0s
# [CV 2/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.535 total time=  37.3s
# [CV 3/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.581 total time=  37.3s
# [CV 4/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.547 total time=  37.6s
# [CV 5/5] END learning_rate=0.001, max_depth=7, n_estimators=800;, score=0.573 total time=  39.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.553 total time=   3.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.574 total time=   3.5s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.611 total time=   3.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.599 total time=   3.5s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=200;, score=0.598 total time=   3.7s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.574 total time=   7.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.568 total time=   7.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.605 total time=   7.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.614 total time=   7.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.579 total time=   7.3s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.565 total time=  14.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.553 total time=  14.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.611 total time=  14.4s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.590 total time=  14.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=800;, score=0.573 total time=  14.7s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.532 total time=   6.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.553 total time=   5.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.605 total time=   5.9s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.581 total time=   5.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=200;, score=0.582 total time=   6.2s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.562 total time=  12.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.559 total time=  11.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.587 total time=  11.8s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.581 total time=  11.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.585 total time=  11.5s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.544 total time=  22.9s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.550 total time=  22.9s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.581 total time=  23.4s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.608 total time=  22.8s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=800;, score=0.591 total time=  26.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.547 total time=   9.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.547 total time=   9.5s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.574 total time=   9.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.581 total time=   9.3s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=200;, score=0.582 total time=   9.6s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.556 total time=  18.4s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.535 total time=  18.0s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.571 total time=  17.7s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.578 total time=  17.7s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=400;, score=0.564 total time=  19.0s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.571 total time=  38.6s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.529 total time=  36.6s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.574 total time=  36.4s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.599 total time=  35.4s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=800;, score=0.579 total time=  37.1s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.562 total time=   3.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.538 total time=   3.5s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.590 total time=   3.5s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.553 total time=   3.5s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=200;, score=0.570 total time=   4.4s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.556 total time=   7.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.535 total time=   7.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.578 total time=   7.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.571 total time=   7.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.582 total time=   6.9s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.541 total time=  13.4s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.520 total time=  13.5s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.550 total time=  13.3s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.553 total time=  13.5s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=800;, score=0.573 total time=  13.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.547 total time=   5.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.523 total time=   5.7s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.571 total time=   5.6s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.565 total time=   5.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=200;, score=0.591 total time=   5.6s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.544 total time=  10.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.520 total time=  10.7s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.593 total time=  10.5s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.547 total time=  10.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.576 total time=  10.7s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.547 total time=  18.6s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.529 total time=  18.8s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.581 total time=  18.9s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.541 total time=  19.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=800;, score=0.558 total time=  19.0s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.571 total time=   8.6s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.532 total time=   8.6s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.574 total time=   8.5s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.574 total time=   8.6s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=200;, score=0.607 total time=   8.7s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.544 total time=  14.0s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.523 total time=  14.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.584 total time=  14.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.562 total time=  14.1s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=400;, score=0.585 total time=  14.3s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.553 total time=  18.8s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.526 total time=  18.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.574 total time=  19.0s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.562 total time=  18.8s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=800;, score=0.573 total time=  19.0s
# Time to complete Grid Search: 1837.405786 seconds
# Time to complete prediction: 0.018416 seconds
# Total time to complete Grid Search and prediction: 1837.424202 seconds

# %%
# Calculate metrics
accuracy_2 = accuracy_score(y_val, y_pred_2)
# the following metrics need to include the average type since the validation is ordinal and not binary
f1_2 = f1_score(y_val, y_pred_2, average= 'weighted')
precision_2 = precision_score(y_val, y_pred_2, average= 'weighted')
recall_2 = recall_score(y_val, y_pred_2, average= 'weighted')
kappa_scaled_2 = cohen_kappa_score(y_val, y_pred_2, weights='quadratic')

print(f"Second model scores:")
print("-------------------")
print(f"Best Estimators: {best_gb_2.n_estimators}")
print(f"Best Learning Rate: {best_gb_2.learning_rate}")
print(f"Best Max Depth: {best_gb_2.max_depth}")
print(f"Accuracy: {accuracy_2:.2f}")
print(f"F1: {f1_2:.2f}")
print(f"Precision: {precision_2:.2f}")
print(f"Recall: {recall_2:.2f}")
print(f"Cohen Kappa Score, quadratic weighted: {kappa_scaled_2:.4f}")
# Out:
# Second model scores:
# -------------------
# Best Estimators: 400
# Best Learning Rate: 0.01
# Best Max Depth: 3
# Accuracy: 0.59
# F1: 0.57
# Precision: 0.58
# Recall: 0.59
# Cohen Kappa Score, quadratic weighted: 0.4534

# %% [markdown]
# # Compare Scaled and Original Datasets
# It seams there is no difference in computation time or kappa scores between the scaled and unscaled (original) datasets.

# %%
print("--------------------------------------------------------")

best_hp = grid_search.best_params_
print(f"First Grad Boosted Model best hyperparameters: ")
print(f"     {best_hp}")
print()
print("--------------------------------------------------------")
print(f"First Grad Boosted Model Classification Report")
print(classification_report(y_val,y_pred))
print()
print("--------------------------------------------------------")
score = cohen_kappa_score(y_val, y_pred, weights='quadratic')
print()
print(f"First Grad Boosted Quadratic Weighted Kappa score: {score:.3f}")
print()
print("--------------------------------------------------------")
# Out:
# --------------------------------------------------------
# First Grad Boosted Model best hyperparameters:
#      {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}
#
# --------------------------------------------------------
# First Grad Boosted Model Classification Report
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       1.00      0.12      0.22         8
#            5       0.65      0.74      0.69       169
#            6       0.52      0.60      0.56       158
#            7       0.61      0.32      0.42        69
#            8       0.00      0.00      0.00         6
#
#     accuracy                           0.59       412
#    macro avg       0.46      0.30      0.32       412
# weighted avg       0.59      0.59      0.57       412
#
#
# --------------------------------------------------------
#
# First Grad Boosted Quadratic Weighted Kappa score: 0.465
#
# --------------------------------------------------------

# %%
# Create the figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot the first confusion matrix
axs[0].set_title("First Model Confusion Matrix")
conf_matrix_display_1 = ConfusionMatrixDisplay.from_predictions(y_val, y_pred, ax=axs[0])
# conf_matrix_display_1.plot(cmap=plt.cm.Blues, ax=axs[0])

# Calculate sample_weight
sample_weight = (y_pred != y_val)

# Plot the second confusion matrix
axs[1].set_title("Normalized First Model Confusion Matrix")
conf_matrix_display_2 = ConfusionMatrixDisplay.from_predictions(y_val, y_pred,
                                                              #  sample_weight=sample_weight,
                                                               normalize='true',
                                                               values_format='.0%',
                                                               ax=axs[1])
# conf_matrix_display_2.plot(cmap=plt.cm.Blues, ax=axs[1])

# Adjust layout
plt.suptitle(f"Confusion Matrix of Gradient Boosted Model", fontsize = 24)
plt.suptitle(f"")
plt.suptitle(f"Model Parameters: {best_hp}")
plt.tight_layout()
plt.savefig(f"{gb_output_path}/gb_first_model_confusion_matrix.png")
plt.show()

# %%
print("--------------------------------------------------------")

best_hp_2 = grid_search_2.best_params_
print(f"First Grad Boosted Model best hyperparameters: ")
print(f"     {best_hp_2}")
print()
print("--------------------------------------------------------")
print(f"First Grad Boosted Model Classification Report")
print(classification_report(y_val,y_pred_2))
print()
print("--------------------------------------------------------")
score_2 = cohen_kappa_score(y_val, y_pred_2, weights='quadratic')
print()
print(f"Second Grad Boosted Quadratic Weighted Kappa score: {score_2:.3f}")
print()
print("--------------------------------------------------------")
# Out:
# --------------------------------------------------------
# First Grad Boosted Model best hyperparameters:
#      {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400}
#
# --------------------------------------------------------
# First Grad Boosted Model Classification Report
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       1.00      0.12      0.22         8
#            5       0.65      0.73      0.69       169
#            6       0.52      0.59      0.56       158
#            7       0.57      0.35      0.43        69
#            8       0.00      0.00      0.00         6
#
#     accuracy                           0.59       412
#    macro avg       0.46      0.30      0.32       412
# weighted avg       0.58      0.59      0.57       412
#
#
# --------------------------------------------------------
#
# Second Grad Boosted Quadratic Weighted Kappa score: 0.453
#
# --------------------------------------------------------

# %%
# Create the figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot the first confusion matrix
axs[0].set_title("Second Model Confusion Matrix")
conf_matrix_display_1 = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2, ax=axs[0])
# conf_matrix_display_1.plot(cmap=plt.cm.Blues, ax=axs[0])

# Calculate sample_weight
sample_weight = (y_pred != y_val)

# Plot the second confusion matrix
axs[1].set_title("Normalized Second Model Confusion Matrix")
conf_matrix_display_2 = ConfusionMatrixDisplay.from_predictions(y_val, y_pred_2,
                                                            #    sample_weight=sample_weight,
                                                               normalize='true',
                                                               values_format='.0%',
                                                               ax=axs[1])
# conf_matrix_display_2.plot(cmap=plt.cm.Blues, ax=axs[1])

# Adjust layout
plt.tight_layout()
plt.savefig(f"{gb_output_path}/gb_second_model_confusion_matrix.png")
plt.show()
